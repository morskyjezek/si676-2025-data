# %% [markdown]
# # JSON (Dictionaries) & APIs
#
# This notebook introduces Python dictionaries and provides a walkthrough of using the `requests` library
# to retrieve data from a REST API.
#
# ## Contents
#
# * Working with [JSON in Python](https://docs.python.org/3/library/json.html)
#   * `.load()`
#   * `.loads()`
#   * `.dump()`
#   * `.dumps()`
# * Using [Requests](https://requests.readthedocs.io/en/latest/)
#   * Allows you to use python to make HTTP requests, then create an API call
#   * Use a dictionary for paramters
#   * Make an API call
#   * Save to a local file

# %% [markdown]
# ### Reading JSON into Python
#
# To convert JSON into a processable object for python, use the JSON module and the `.loads()` function. For example:

# %%
import json

# %%
stringOfJsonData = '{ "Results": 2, "isPrinted" : true, "format" : null, "books": [{ "title": "Gone with the Wind", "author":"Mitchell" },{ "title": "Wuthering Heights", "author": "Bronte" } ]}'

jsonDataAsPythonValue = json.loads(stringOfJsonData)

jsonDataAsPythonValue
# Out:
# {'Results': 2,
#  'isPrinted': True,
#  'format': None,
#  'books': [{'title': 'Gone with the Wind', 'author': 'Mitchell'},
#   {'title': 'Wuthering Heights', 'author': 'Bronte'}]}

# %%
for key in jsonDataAsPythonValue:
    print(key)
# Out:
# Results
# isPrinted
# format
# books

# %% [markdown]
# Print the keys & values

# %%
for key in jsonDataAsPythonValue:
    print(key, ':', jsonDataAsPythonValue[key])
# Out:
# Results : 2
# isPrinted : True
# format : None
# books : [{'title': 'Gone with the Wind', 'author': 'Mitchell'}, {'title': 'Wuthering Heights', 'author': 'Bronte'}]

# %%
for book in jsonDataAsPythonValue['books']:
    print(book)
# Out:
# {'title': 'Gone with the Wind', 'author': 'Mitchell'}
# {'title': 'Wuthering Heights', 'author': 'Bronte'}

# %% [markdown]
# Another possibility is to assign the data element you want to a variable (e.g., `books` below).
# Then, you can continue to work with that data on its own:

# %%
books = jsonDataAsPythonValue['books']

for book in books:
    print(book)
# Out:
# {'title': 'Gone with the Wind', 'author': 'Mitchell'}
# {'title': 'Wuthering Heights', 'author': 'Bronte'}

# %% [markdown]
# ### Writing JSON from Python
#
# To write out the data into a JSON file, use the `.dumps()` function. For example:

# %%
jsonDataAsPythonValue
# Out:
# {'Results': 2,
#  'isPrinted': True,
#  'format': None,
#  'books': [{'title': 'Gone with the Wind', 'author': 'Mitchell'},
#   {'title': 'Wuthering Heights', 'author': 'Bronte'}]}

# %%
# uncomment next line if you haven't yet imported the json module
#import json

stringOfJsonData = json.dumps(jsonDataAsPythonValue)

stringOfJsonData
# Out:
# '{"Results": 2, "isPrinted": true, "format": null, "books": [{"title": "Gone with the Wind", "author": "Mitchell"}, {"title": "Wuthering Heights", "author": "Bronte"}]}'

# %%
# write to a file

with open('../data/json-books.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(jsonDataAsPythonValue, indent=2))
    print('wrote',f.name)
# Out:
# wrote ../data/json-books.json

# %% [markdown]
# Next, we will use the JSON techniques to parse and process the data from an API response. The response is providing us a serialization of metadata in JSON.

# %% [markdown]
# ## Making an API call
#
# ### First, using requests
#
# Let's use requests to scrape some data from an API endpoint. In this case, we can use the Library of Congress
# search function, which is a REST API that responds to HTTP requests.
#
# The documentation for requests can be found here: http://docs.python-requests.org/en/master/
#
# The endpoint for the search query is `http://www.loc.gov/search/`

# %%
import requests

searchEndpoint = 'http://www.loc.gov/search/'

# %% [markdown]
# To pass in the parameters, we can use a dictionary! Let's try using `params`

# %%
parameters = {
    'fo' : 'json',
    'q'  : 'kittens',
    'fa' : 'online-format:image'
}

# %%
r = requests.get(searchEndpoint, params = parameters)

print('You requested:',r.url)
print('HTTP server response code:',r.status_code)
print('HTTP response headers',r.headers)

# notice that the headers method returns a dictionary, too? 
# We could ask what sort of content it's returning:

print('\nYour request has this content type:\n',r.headers['content-type'])
# Out:
# You requested: https://www.loc.gov/search/?fa=online-format%3Aimage&fo=json&q=kittens
# HTTP server response code: 200
# HTTP response headers {'Date': 'Fri, 03 Oct 2025 19:34:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '181741', 'Connection': 'keep-alive', 'CF-RAY': '988ee0f34f524f3f-ORD', 'Access-Control-Allow-Origin': '*', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Strict-Transport-Security': 'max-age=3600; preload', 'X-Content-Type-Options': 'nosniff', 'X-Robots-Tag': 'noindex, nofollow', 'X-Frame-Options': 'sameorigin', 'ETag': '"10eee7ccf8e3dd696372d98673c433dd"', 'Expires': 'Fri, 03 Oct 2025 23:11:52 GMT', 'Content-Security-Policy': "block-all-mixed-content;         default-src https://loc.gov/ https://*.loc.gov/ ;         media-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             blob:;         worker-src https://loc.gov/ https://*.loc.gov/              blob:;         font-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             data:;         img-src https://loc.gov/ https://*.loc.gov/              https://congress.gov/ https://*.congress.gov/             https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://*.ssa.gov/             https://dpm.demdex.net/             https://cm.everesttech.net/             https://*.amazonaws.com             data:             blob:;         connect-src https://loc.gov/ https://*.loc.gov/              https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://chat-us.libanswers.com/             https://thelibraryofcongress.tt.omtrdc.net/             https://dpm.demdex.net/ \t        https://d3c605m4lmznjl.cloudfront.net/             https://*.s3.us-east-1.amazonaws.com/;         style-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.ssa.gov/             'unsafe-inline'             blob:;         script-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.arcgis.com/ https://*.arcgisonline.com/  https://webapps-cdn.esri.com/             https://ssl.p.jwpcdn.com/             https://assets.adobedtm.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://ajax.googleapis.com/ajax/libs/jquery/             https://*.ssa.gov/             https://s.ytimg.com/             'unsafe-inline'             'unsafe-eval';         frame-src https://loc.gov/ https://*.loc.gov/              https://*.readspeaker.com/             https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://www.nlstalkingbooks.org/             https://unitedstateslibraryofcongress.demdex.net             https://www.youtube-nocookie.com/;         frame-ancestors https://loc.gov/ https://*.loc.gov/              https://*.blackbaudcdn.net/ https://*.blackbaud.com/             https://loc.libwizard.com/;         report-uri https://errorlogging.loc.gov/api/51/security/?sentry_key=2176ae0b9acd4cd59297edc0e064cc95&sentry_environment=production ;", 'X-Grace': 'none', 'X-Nearside-Cache': 'MISS', 'X-Nearside-Cache-Hits': '0', 'Cache-Control': 'no-transform, max-age=86400', 'Age': '73372', 'CF-Cache-Status': 'HIT', 'Accept-Ranges': 'bytes', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare'}
#
# Your request has this content type:
#  application/json

# %% [markdown]
# So the request has returned a json object! Access the response using the `.text` method.

# %%
r.text[:500]
# Out:
# '{"breadcrumbs": [{"Library of Congress": "https://www.loc.gov"}, {"Search": "https://www.loc.gov/search/?fa=online-format:image&fo=json&q=kittens"}], "expert_resources": null, "facet_trail": [{"facet": "searchTerms", "field": "searchTerms", "superset": "https://www.loc.gov/search/?fa=online-format:image&fo=json", "value": "kittens"}, {"facet": "Available Online", "field": "digitized", "superset": "https://www.loc.gov/search/?all=true&fa=online-format:image&fo=json&q=kittens", "value": "digitized'

# %%
for element in r.json():
    print(element)
# Out:
# breadcrumbs
# expert_resources
# facet_trail
# facet_views
# facets
# form_facets
# notice
# options
# pagination
# results
# search
# timestamp
# views

# %%
r.json()['pagination']['total']
# Out:
# 7551

# %%
type(r.text)
# Out:
# str

# %% [markdown]
# #### API Call question
#
# We made a request to the loc.gov JSON API. Can you fill in the following & explain the missing elements?
#
# ```
# http://www.loc.gov/_______/?fo=_______&q=_______
# ```
#
# What other items might you use after the `?`...

# %% [markdown]
# ### Parsing the Data from the API
#
# Now, we can get the response, let's save to a file. To do this, use the `json` module.

# %%
import json

# %%
data = json.loads(r.text)

# what are the keys?
for element in data:
    print(element)
# Out:
# breadcrumbs
# expert_resources
# facet_trail
# facet_views
# facets
# form_facets
# notice
# options
# pagination
# results
# search
# timestamp
# views

# %%
for item in data['results']:
    print(item)
# Out:
# {'access_restricted': False, 'aka': ['http://www.loc.gov/pictures/collection/hec/item/2016892679/', 'http://www.loc.gov/item/2016892679/', 'http://www.loc.gov/pictures/item/2016892679/', 'https://hdl.loc.gov/loc.pnp/hec.43433', 'http://www.loc.gov/resource/hec.43433/', 'http://lccn.loc.gov/2016892679'], 'campaigns': [], 'contributor': ['harris & ewing'], 'date': '1923-01-01', 'dates': ['1923'], 'description': ['1 negative : glass ; 4 x 5 in. or smaller'], 'digitized': True, 'extract_timestamp': '2021-09-01T22:39:14.884Z', 'group': ['hec', 'catalog-split-02', 'catalog', 'harris-ewing', 'main-catalog-split-02', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2016892679/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433_150px.jpg#h=116&w=150', 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433t.gif#h=116&w=150', 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433r.jpg#h=496&w=640', 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433v.jpg#h=793&w=1024'], 'index': 1, 'item': {'call_number': 'LC-H234- A-7079 [P&P]', 'contributors': ['Harris & Ewing, photographer.'], 'control_number': '2016892679', 'created': '2018-01-17T19:29:15Z', 'created_published': '[1923]', 'created_published_date': '[1923]', 'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Harris%20%26%20Ewing&co=hec', 'role': 'photographer', 'title': 'Harris & Ewing'}], 'date': '[1923]', 'digital_id': ['hec 43433 //hdl.loc.gov/loc.pnp/hec.43433'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Glass%20negatives.&co=hec', 'title': 'Glass negatives.'}], 'genre': ['Glass negatives'], 'id': '2016892679', 'language': ['eng'], 'link': '//www.loc.gov/pictures/item/2016892679/', 'marc': '//www.loc.gov/pictures/item/2016892679/marc/', 'medium': ['1 negative : glass ; 4 x 5 in. or smaller'], 'medium_brief': '1 negative :', 'mediums': ['1 negative : glass ; 4 x 5 in. or smaller'], 'modified': '2018-01-17T19:29:15Z', 'notes': ['Title devised by Library staff.', 'Date based on date of negatives in same range.', 'Gift; Harris & Ewing, Inc. 1955.', 'General information about the Harris & Ewing Collection is available at http://hdl.loc.gov/loc.pnp/pp.hec', 'Temp. note: Batch eight.'], 'number_former_id': ['https://www.loc.gov/item/2016892679', 'https://www.loc.gov/item/hec2013013458'], 'other_control_numbers': ['20269443', 'hec2013013458'], 'part_of': 'Harris & Ewing photograph collection', 'place': [{'latitude': '', 'link': '//www.loc.gov/pictures/related/?fi=place&q=United%20States&co=hec', 'longitude': '', 'title': 'United States'}], 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-hec-43433 (digital file from original negative)', 'resource_links': ['//hdl.loc.gov/loc.pnp/hec.43433'], 'rights_advisory': 'No known restrictions on publication. For more information, see Harris & Ewing Photographs - Rights and Restrictions Information https://www.loc.gov/rr/print/res/140_harr.html', 'rights_information': 'No known restrictions on publication. For more information, see Harris & Ewing Photographs - Rights and Restrictions Information https://www.loc.gov/rr/print/res/140_harr.html', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433r.jpg', 'sort_date': '1923', 'source_collection': ['Harris & Ewing photograph collection'], 'source_created': '2013-04-04T00:00:00Z', 'source_modified': '2018-01-10T14:05:18Z', 'subject_headings': ['United States.', 'United States'], 'subjects': ['United States'], 'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/hec/43400/43433_150px.jpg', 'title': '[Kittens]'}, 'language': ['english'], 'location': ['united states'], 'location_ ...
# {'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2017650796/', 'http://www.loc.gov/item/2017650796/', 'http://www.loc.gov/pictures/item/2017650796/', 'https://www.loc.gov/pictures/collection/pga/item/2017650796/', 'http://www.loc.gov/pictures/collection/pga/item/2017650796/', 'http://www.loc.gov/resource/pga.12657/', 'http://lccn.loc.gov/2017650796', 'https://hdl.loc.gov/loc.pnp/pga.12657'], 'campaigns': [], 'contributor': ['ronner, henriette', 'schaus, w. (william)'], 'date': '1867-01-01', 'dates': ['1867'], 'description': ['1 print : chromolithograph ; sheet 31.6 x 22.3 cm. | Print shows a cat with three kittens at a green food or water dish, with a basket of straw in a room where the floor is also strewn with straw.'], 'digitized': True, 'extract_timestamp': '2021-06-28T23:51:17.725Z', 'group': ['pga', 'catalog-split-11', 'catalog', 'popular-graphic-arts', 'main-catalog-split-11', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2017650796/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/pga/12600/12657_150px.jpg#h=150&w=111', 'https://tile.loc.gov/storage-services/service/pnp/pga/12600/12657r.jpg#h=640&w=472', 'https://tile.loc.gov/storage-services/service/pnp/pga/12600/12657v.jpg#h=1024&w=755'], 'index': 2, 'item': {'call_number': 'PGA - Schaus (W.)--Cat and kittens (A size) [P&P]', 'contributor_names': ['Ronner, Henriette, 1821-1909, artist '], 'contributors': ['Schaus, W. (William), publisher, copyright claimant.', 'Ronner, Henriette, 1821-1909, artist.'], 'control_number': '2017650796', 'created': '2017-11-21T04:14:50Z', 'created_published': '[New York] : Published by W. Schaus, 749 Broadway, N.Y., [1867]', 'created_published_date': '[1867]', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Schaus%2C%20W.%20%28William%29&co=pga', 'role': 'publisher', 'title': 'Schaus, W. (William)'}, {'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Schaus%2C%20W.%20%28William%29&co=pga', 'role': 'copyright claimant', 'title': 'Schaus, W. (William)'}, {'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Ronner%2C%20Henriette%2C%201821-1909&co=pga', 'role': 'artist', 'title': 'Ronner, Henriette, 1821-1909'}], 'date': '[1867]', 'digital_id': ['pga 12657 //hdl.loc.gov/loc.pnp/pga.12657'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Chromolithographs--Color--1860-1870.&co=pga', 'title': 'Chromolithographs--Color--1860-1870.'}], 'genre': ['Chromolithographs--Color--1860-1870'], 'id': '2017650796', 'language': ['eng'], 'link': 'https://www.loc.gov/pictures/item/2017650796/', 'marc': 'https://www.loc.gov/pictures/item/2017650796/marc/', 'medium': ['1 print : chromolithograph ; sheet 31.6 x 22.3 cm.'], 'medium_brief': '1 print :', 'mediums': ['1 print : chromolithograph ; sheet 31.6 x 22.3 cm.'], 'modified': '2017-11-21T04:14:50Z', 'notes': ['Title from item.', 'From series: Fac-similes of Water Color Drawings and Oil Paintings by eminent artists, published by W. Schaus, 749 Broadway, N.Y.', 'Publication date based on copyright statement on item.', 'Copyright statement appears on label attached to item.', 'Inscribed in pencil on verso: 5341.', 'Forms part of: Popular graphic art print filing series (Library of Congress).'], 'other_control_numbers': ['20114389'], 'part_of': 'Popular graphic art print filing series (Library of Congress)', 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-pga-12657 (digital file from original print)', 'resource_links': ['//hdl.loc.gov/loc.pnp/pga.12657'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/pga/12600/12657_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/ser ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/item/jukebox-668708/', 'http://www.loc.gov/resource/jukebox-668708.0/', 'http://www.loc.gov/resource/jukebox-668708.1/', 'http://www.loc.gov/resource/jukebox-668708.0', 'http://www.loc.gov/resource/jukebox-668708.1'], 'campaigns': [], 'contributor': ['confrey, zez', 'austin, jack', 'banta, frank e.'], 'contributor_composer': ['confrey, zez'], 'contributor_primary': ['banta, frank e.'], 'date': '1922-07-29', 'dates': ['1922-07-29'], 'description': ['Columbia A3687. Matrix/Take: 80480/3.'], 'digitized': True, 'extract_timestamp': '2025-08-15T12:05:25.641Z', 'group': ['nationaljukebox', 'national-jukebox'], 'hassegments': False, 'id': 'http://www.loc.gov/item/jukebox-668708/', 'image_url': ['https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/pct:12.5/0/default.jpg#h=361&w=361', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/pct:25/0/default.jpg#h=723&w=723', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/pct:50/0/default.jpg#h=1446&w=1446', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/pct:100/0/default.jpg#h=2893&w=2893'], 'index': 3, 'item': {'audio_type': 'Instrumental', 'contributors': ['Banta, Frank E. -- Instrumentalist -- Piano', 'Austin, Jack -- Instrumentalist -- Piano', 'Confrey, Zez -- Composer -- Composer'], 'file_id': ['ucsb_col_a3687_01_80480_03'], 'genre': ['Popular music', 'Popular music'], 'media_size': '10-in.', 'profile': 'jukebox', 'recording_catalog_number': 'A3687', 'recording_date': '1922-07-29', 'recording_label': 'Columbia', 'recording_location': 'New York, New York', 'recording_matrix_number': '80480 (Matrix ID)', 'recording_repository': 'Source of original recording: Department of Special Collections, Davidson Library, University of California, Santa Barbara.', 'recording_take_id': 668708, 'recording_take_number': '3', 'rights_advisory': 'Inclusion of the recording in the National Jukebox, courtesy of Sony Music Entertainment or EMI Music', 'summary': 'Piano duet'}, 'location': ['united states', 'new york'], 'mime_type': ['audio/mpeg', 'audio/wav', 'image/tif', 'image/jpeg'], 'online_format': ['audio', 'image'], 'original_format': ['sound recording'], 'partof': ['department of special collections, davidson library, university of california, santa barbara', 'recorded sound research center', 'national jukebox'], 'partof_repository': ['department of special collections, davidson library, university of california, santa barbara'], 'resources': [{'files': 1, 'media': 'https://tile.loc.gov/streaming-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/full/0/full/default.mp3', 'url': 'https://www.loc.gov/resource/jukebox-668708.0'}, {'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:ucsb_col_a3687_01_80480_03:ucsb_col_a3687_01_80480_03/full/pct:100/0/default.jpg', 'mimetype': 'image/jpeg', 'url': 'https://www.loc.gov/resource/jukebox-668708.1'}], 'shelf_id': 'Columbia A3687', 'site': ['nationaljukebox'], 'subject': ['popular music', 'columbia', 'instrumental'], 'subject_category': ['instrumental'], 'subject_genre': ['popular music'], 'subject_label': ['columbia'], 'timestamp': '2025-08-15T12:30:22.849Z', 'title': 'Kitten on the keys', 'type': ['sound recording-musical'], 'url': 'https://www.loc.gov/item/jukebox-668708/'}
# {'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2013646722/', 'http://www.loc.gov/item/2013646722/', 'http://www.loc.gov/pictures/item/2013646722/', 'https://www.loc.gov/pictures/collection/pga/item/2013646722/', 'http://www.loc.gov/pictures/collection/pga/item/2013646722/', 'http://www.loc.gov/resource/pga.05131/', 'http://lccn.loc.gov/2013646722', 'https://hdl.loc.gov/loc.pnp/pga.05131'], 'campaigns': [], 'contributor': ['anderson, alexander'], 'date': '1810-01-01', 'dates': ['1810'], 'description': ['1 print : wood engraving ; 5.2 x 7.2 cm (image), 10.4 x 12.9 cm (sheet) | Print shows a cat with three kittens.'], 'digitized': True, 'extract_timestamp': '2021-06-28T21:56:23.719Z', 'group': ['pga', 'catalog-split-01', 'catalog', 'popular-graphic-arts', 'main-catalog-split-01', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2013646722/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131_150px.jpg#h=122&w=150', 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131t.gif#h=122&w=150', 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131r.jpg#h=521&w=640', 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131v.jpg#h=834&w=1024'], 'index': 4, 'item': {'call_number': 'PGA - Anderson (A.)--Mother cat ... (A size) [P&P]', 'contributors': ['Anderson, Alexander, 1775-1870, engraver.'], 'control_number': '2013646722', 'created': '2016-04-21T01:25:13Z', 'created_published': '[between 1810 and 1860]', 'created_published_date': '[between 1810 and 1860]', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Anderson%2C%20Alexander%2C%201775-1870&co=pga', 'role': 'engraver', 'title': 'Anderson, Alexander, 1775-1870'}], 'date': '[between 1810 and 1860]', 'digital_id': ['pga 05131 //hdl.loc.gov/loc.pnp/pga.05131'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Wood%20engravings--1810-1870.&co=pga', 'title': 'Wood engravings--1810-1870.'}], 'genre': ['Wood engravings--1810-1870'], 'id': '2013646722', 'language': ['eng'], 'link': 'https://www.loc.gov/pictures/item/2013646722/', 'marc': 'https://www.loc.gov/pictures/item/2013646722/marc/', 'medium': ['1 print : wood engraving ; 5.2 x 7.2 cm (image), 10.4 x 12.9 cm (sheet)'], 'medium_brief': '1 print :', 'mediums': ['1 print : wood engraving ; 5.2 x 7.2 cm (image), 10.4 x 12.9 cm (sheet)'], 'modified': '2016-04-21T01:25:13Z', 'notes': ['Title devised by Library staff.', '(DLC/PP-1908:43450.2).'], 'other_control_numbers': ['17767584'], 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-pga-05131 (digital file from original print)', 'resource_links': ['//hdl.loc.gov/loc.pnp/pga.05131'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131r.jpg', 'sort_date': '1810', 'source_created': '2013-06-07T00:00:00Z', 'source_modified': '2013-06-07T07:16:35Z', 'stmt_of_responsibility': 'A.A.', 'subject_headings': ['Cats--1810-1860.'], 'subjects': ['Cats--1810-1860'], 'summary': 'Print shows a cat with three kittens.', 'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/pga/05100/05131_150px.jpg', 'title': '[Mother cat and kittens]'}, 'language': ['english'], 'mime_type': ['image/gif', 'image/jpg', 'image/tif'], 'number': ['http://www.loc.gov/item/17767584', '2013646722', '2013-06-07t07:16:35'], 'number_former_id': ['http://www.loc.gov/item/17767584'], 'number_lccn': ['2013646722'], 'number_source_modified': ['2013-06-07t07:16:35'], 'online_format': ['image'], 'original_format': ['photo, print, drawing'], 'partof': ['catalog', 'prin ...
# {'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2022653071/', 'http://www.loc.gov/item/2022653071/', 'http://www.loc.gov/pictures/item/2022653071/', 'https://www.loc.gov/pictures/collection/stereo/item/2022653071/', 'http://www.loc.gov/pictures/collection/stereo/item/2022653071/', 'https://hdl.loc.gov/loc.pnp/stereo.1s44810', 'https://hdl.loc.gov/loc.pnp/stereo.1s44810', 'http://www.loc.gov/resource/stereo.1s44810/', 'http://lccn.loc.gov/2022653071'], 'campaigns': [], 'date': '1876-01-01', 'dates': ['1876'], 'description': ['1 photograph : print ; mount 9 x 18 cm (stereograph format)'], 'digitized': True, 'extract_timestamp': '2023-03-15T02:28:06.660Z', 'group': ['stereo', 'catalog-split-12', 'catalog', 'stereograph-cards', 'main-catalog-split-12', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2022653071/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810_150px.jpg#h=94&w=150', 'https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810r.jpg#h=400&w=640', 'https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810v.jpg#h=640&w=1024'], 'index': 5, 'item': {'call_number': 'LOT 7756 [item] [P&P]', 'control_number': '2022653071', 'created': '2022-09-06T06:03:30Z', 'created_published': '1876.', 'digital_id': ['stereo 1s44810 https://hdl.loc.gov/loc.pnp/stereo.1s44810'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--1870-1880.&co=stereo', 'title': 'Photographic prints--1870-1880.'}, {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Stereographs--1870-1880.&co=stereo', 'title': 'Stereographs--1870-1880.'}], 'genre': ['Stereographs--1870-1880', 'Photographic prints--1870-1880'], 'id': '2022653071', 'language': ['eng'], 'link': 'https://www.loc.gov/pictures/item/2022653071/', 'marc': 'https://www.loc.gov/pictures/item/2022653071/marc/', 'medium': ['1 photograph : print ; mount 9 x 18 cm (stereograph format)'], 'medium_brief': '1 photograph :', 'mediums': ['1 photograph : print ; mount 9 x 18 cm (stereograph format)'], 'modified': '2022-09-06T06:03:30Z', 'notes': ['Title transcribed from item.', 'No. 2563.'], 'other_control_numbers': ['22775125'], 'raw_collections': ['diof', 'pp', 'stereo'], 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA https://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-stereo-1s44810 (digital file from original)', 'resource_links': ['https://hdl.loc.gov/loc.pnp/stereo.1s44810'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810r.jpg', 'sort_date': '1876', 'source_created': '2022-09-01T00:00:00Z', 'source_modified': '2022-09-01T17:20:31Z', 'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/stereo/1s40000/1s44000/1s44800/1s44810_150px.jpg', 'title': 'The sick kitten'}, 'language': ['english'], 'mime_type': ['image/gif', 'image/jpg', 'image/tif'], 'number': ['2022-09-01t17:20:31', 'sheet', 'http://www.loc.gov/item/22775125', '2022653071'], 'number_carrier_type': ['sheet'], 'number_former_id': ['http://www.loc.gov/item/22775125'], 'number_lccn': ['2022653071'], 'number_source_modified': ['2022-09-01t17:20:31'], 'online_format': ['image'], 'original_format': ['photo, print, drawing'], 'partof': ['prints and photographs division', 'catalog', 'stereograph cards', 'lot 7756', 'prints & photographs online catalog (library of congress)'], 'related': {'group_record': 'https://www.loc.gov/pictures/search/?q=LOT 7756&fi=number&op=PHRASE&va=exact&co=coll&sg=true', 'neighbors': 'https://www ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/pictures/collection/det/item/2016796464/', 'http://www.loc.gov/item/2016796464/', 'http://www.loc.gov/pictures/item/2016796464/', 'https://hdl.loc.gov/loc.pnp/det.4a31106', 'http://www.loc.gov/resource/det.4a31106/', 'http://lccn.loc.gov/2016796464'], 'campaigns': [], 'contributor': ['detroit publishing co.', 'homer, winslow'], 'date': '1900-01-01', 'dates': ['1900'], 'description': ['1 transparency : autochrome, color ; 6.5 x 8.5 in.'], 'digitized': True, 'extract_timestamp': '2021-09-01T22:28:50.302Z', 'group': ['det', 'catalog-split-13', 'catalog', 'detroit-publishing-company', 'main-catalog-split-13', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2016796464/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a30000/4a31000/4a31100/4a31106_150px.jpg#h=119&w=150', 'https://tile.loc.gov/storage-services/service/pnp/det/4a30000/4a31000/4a31100/4a31106t.gif#h=119&w=150', 'https://tile.loc.gov/storage-services/service/pnp/det/4a30000/4a31000/4a31100/4a31106r.jpg#h=420&w=529', 'https://tile.loc.gov/storage-services/service/pnp/det/4a30000/4a31000/4a31100/4a31106v.jpg#h=813&w=1024'], 'index': 6, 'item': {'access_advisory': 'Not available for photoduplication service due to fragility.', 'call_number': 'LC-D415-48020 [P&P]', 'contributor_names': ['Detroit Publishing Co., copyright claimant ', 'Detroit Publishing Co., publisher '], 'contributors': ['Homer, Winslow, 1836-1910, artist.', 'Detroit Publishing Co., copyright claimant, publisher.'], 'control_number': '2016796464', 'created': '2017-11-21T04:48:16Z', 'created_published': '[between 1900 and 1912]', 'created_published_date': '[between 1900 and 1912]', 'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Homer%2C%20Winslow%2C%201836-1910&co=det', 'role': 'artist', 'title': 'Homer, Winslow, 1836-1910'}, {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det', 'role': 'copyright claimant', 'title': 'Detroit Publishing Co.'}, {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det', 'role': 'publisher', 'title': 'Detroit Publishing Co.'}], 'date': '[between 1900 and 1912]', 'digital_id': ['det 4a31106 //hdl.loc.gov/loc.pnp/det.4a31106'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Autochromes--Color.&co=det', 'title': 'Autochromes--Color.'}, {'link': '//www.loc.gov/pictures/related/?fi=format&q=Paintings--Reproductions.&co=det', 'title': 'Paintings--Reproductions.'}], 'genre': ['Autochromes--Color', 'Paintings--Reproductions'], 'id': '2016796464', 'language': ['eng'], 'link': '//www.loc.gov/pictures/item/2016796464/', 'marc': '//www.loc.gov/pictures/item/2016796464/marc/', 'medium': ['1 transparency : autochrome, color ; 6.5 x 8.5 in.'], 'medium_brief': '1 transparency :', 'mediums': ['1 transparency : autochrome, color ; 6.5 x 8.5 in.'], 'modified': '2017-11-21T04:48:16Z', 'notes': ['Date based on Detroit, Thistle Publications (1912).', '"McC-386" on transparency.', 'Photo of watercolor study signed "Homer."', 'Detroit Publishing Co. no. 48020.', 'Gift; State Historical Society of Colorado; 1949.'], 'number_former_id': ['https://www.loc.gov/item/2016796464', 'https://www.loc.gov/item/det1994002421/PP'], 'other_control_numbers': ['20092469', 'det1994002421/PP'], 'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)', 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a31106'], 'restriction': 'Not available for photoduplication service due to fragility.', 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a30000/4a31000/4a31100/4a31106_150px.j ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/pictures/collection/det/item/2016816441/', 'http://www.loc.gov/item/2016816441/', 'http://www.loc.gov/pictures/item/2016816441/', 'https://hdl.loc.gov/loc.pnp/det.4a28544', 'http://www.loc.gov/resource/det.4a28544/', 'http://lccn.loc.gov/2016816441'], 'campaigns': [], 'contributor': ['detroit publishing co.', 'homer, winslow'], 'date': '1900-01-01', 'dates': ['1900'], 'description': ['1 negative : glass ; 11 x 14 in.'], 'digitized': True, 'extract_timestamp': '2021-09-01T22:30:46.547Z', 'group': ['det', 'catalog-split-01', 'catalog', 'detroit-publishing-company', 'main-catalog-split-01', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2016816441/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544_150px.jpg#h=117&w=150', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544t.gif#h=117&w=150', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544r.jpg#h=420&w=538', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544v.jpg#h=799&w=1024'], 'index': 7, 'item': {'call_number': 'LC-D429-48020 [P&P]', 'contributor_names': ['Detroit Publishing Co., publisher '], 'contributors': ['Homer, Winslow, 1836-1910, artist.', 'Detroit Publishing Co., publisher.'], 'control_number': '2016816441', 'created': '2017-11-21T04:54:46Z', 'created_published': '[between 1900 and 1912]', 'created_published_date': '[between 1900 and 1912]', 'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Homer%2C%20Winslow%2C%201836-1910&co=det', 'role': 'artist', 'title': 'Homer, Winslow, 1836-1910'}, {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det', 'role': 'publisher', 'title': 'Detroit Publishing Co.'}], 'date': '[between 1900 and 1912]', 'digital_id': ['det 4a28544 //hdl.loc.gov/loc.pnp/det.4a28544'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Dry%20plate%20negatives.&co=det', 'title': 'Dry plate negatives.'}, {'link': '//www.loc.gov/pictures/related/?fi=format&q=Paintings--Reproductions.&co=det', 'title': 'Paintings--Reproductions.'}], 'genre': ['Dry plate negatives', 'Paintings--Reproductions'], 'id': '2016816441', 'language': ['eng'], 'link': '//www.loc.gov/pictures/item/2016816441/', 'marc': '//www.loc.gov/pictures/item/2016816441/marc/', 'medium': ['1 negative : glass ; 11 x 14 in.'], 'medium_brief': '1 negative :', 'mediums': ['1 negative : glass ; 11 x 14 in.'], 'modified': '2017-11-21T04:54:47Z', 'notes': ['Title from jacket.', 'Listed in Detroit, Thistle Publications (1912).', 'Photograph of a watercolor study signed "Homer."', '"McCormick 386" on negative.', 'Detroit Publishing Co. no. 048020.', 'Gift; State Historical Society of Colorado; 1949.'], 'number_former_id': ['https://www.loc.gov/item/2016816441', 'https://www.loc.gov/item/det1994022402/PP'], 'other_control_numbers': ['20124362', 'det1994022402/PP'], 'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)', 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-D429-48020 (b&w glass neg.)', 'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a28544'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a28000/4a28500/4a28544r.jpg', 'sort_date': '1900', 'source_collection': ['Detroit Publishing Company photograph collection (Library of Congress)'], 'source_created': '1994-01-01T00:00:00Z', 'source_modified': '2017-11-03T11:30:16Z', 'subject_headings': ['Childre ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/pictures/collection/det/item/2016817090/', 'http://www.loc.gov/item/2016817090/', 'http://www.loc.gov/pictures/item/2016817090/', 'https://hdl.loc.gov/loc.pnp/det.4a26199', 'http://www.loc.gov/resource/det.4a26199/', 'http://lccn.loc.gov/2016817090'], 'campaigns': [], 'contributor': ['hunt, william morris', 'detroit publishing co.'], 'date': '1900-01-01', 'dates': ['1900'], 'description': ['1 negative : glass ; 8 x 10 in.'], 'digitized': True, 'extract_timestamp': '2021-09-01T22:30:50.170Z', 'group': ['det', 'catalog-split-02', 'catalog', 'detroit-publishing-company', 'main-catalog-split-02', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2016817090/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199_150px.jpg#h=150&w=120', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199t.gif#h=150&w=120', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199r.jpg#h=640&w=511', 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199v.jpg#h=1024&w=818'], 'index': 8, 'item': {'call_number': 'LC-D416-505 [P&P]', 'contributor_names': ['Detroit Publishing Co., copyright claimant ', 'Detroit Publishing Co., publisher '], 'contributors': ['Hunt, William Morris, 1824-1879, artist.', 'Detroit Publishing Co., copyright claimant, publisher.'], 'control_number': '2016817090', 'created': '2017-11-21T03:53:41Z', 'created_published': 'c[between 1900 and 1912]', 'created_published_date': 'c[between 1900 and 1912]', 'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Hunt%2C%20William%20Morris%2C%201824-1879&co=det', 'role': 'artist', 'title': 'Hunt, William Morris, 1824-1879'}, {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det', 'role': 'copyright claimant', 'title': 'Detroit Publishing Co.'}, {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det', 'role': 'publisher', 'title': 'Detroit Publishing Co.'}], 'date': 'c[between 1900 and 1912]', 'digital_id': ['det 4a26199 //hdl.loc.gov/loc.pnp/det.4a26199'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Dry%20plate%20negatives.&co=det', 'title': 'Dry plate negatives.'}, {'link': '//www.loc.gov/pictures/related/?fi=format&q=Paintings--Reproductions.&co=det', 'title': 'Paintings--Reproductions.'}], 'genre': ['Dry plate negatives', 'Paintings--Reproductions'], 'id': '2016817090', 'language': ['eng'], 'link': '//www.loc.gov/pictures/item/2016817090/', 'marc': '//www.loc.gov/pictures/item/2016817090/marc/', 'medium': ['1 negative : glass ; 8 x 10 in.'], 'medium_brief': '1 negative :', 'mediums': ['1 negative : glass ; 8 x 10 in.'], 'modified': '2017-11-21T03:53:41Z', 'notes': ['Date based on Detroit, Thistle Publications (1912).', 'Photograph of a painting at Museum of Fine Arts, Boston.', 'Detroit Publishing Co. no. M 505.', 'Gift; State Historical Society of Colorado; 1949.'], 'number_former_id': ['https://www.loc.gov/item/2016817090', 'https://www.loc.gov/item/det1994023051/PP'], 'other_control_numbers': ['20125039', 'det1994023051/PP'], 'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)', 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-det-4a26199 (digital file from original)', 'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a26199'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a26000/4a26100/4a26199r.jpg', 'sort_date':  ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/item/afc9999005.24310/', 'https://hdl.loc.gov/loc.afc/afc9999005.24310', 'http://www.loc.gov/resource/afc.afc9999005-24310/'], 'campaigns': [], 'contributor': ['creighton, helen', 'mcneil, laura'], 'date': '1948-08-02', 'dates': ['1948-08-02'], 'digitized': True, 'extract_timestamp': '2024-07-10T08:22:35.051Z', 'group': ['paprika-afc'], 'hassegments': False, 'id': 'http://www.loc.gov/item/afc9999005.24310/', 'image_url': ['https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-24310:0817/full/pct:50.0/0/default.jpg', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-24310:0817/full/pct:50.0/0/default.jpg#h=455&w=753', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-24310:0817/full/pct:100.0/0/default.jpg#h=910&w=1506'], 'index': 9, 'item': {'call_number': ['AFS Number: AFS 09265 A', 'AFS Number: AFS 09265 B'], 'contributors': ['Creighton, Helen (Recordist)', 'McNeil, Laura (Speaker)'], 'created_published': ['West Pubnico, Nova Scotia Yarmouth County, Nova Scotia'], 'date': '19480802', 'digital_id': ['https://hdl.loc.gov/loc.afc/afc9999005.24310'], 'format': 'still image', 'genre': ['card catalogs'], 'language': ['eng'], 'location': ['Canada -- Nova Scotia -- Yarmouth County -- West Pubnico'], 'notes': ['This is a digitized catalog card, not an audio recording.', 'Statement of responsibility: Narrator: Mrs. Laura McNeil.'], 'related_items': [{'title': 'Helen Creighton National Museum of Canada Recording Project (AFC 1949/002)', 'url': 'https://lccn.loc.gov/2014655355'}], 'repository': 'american folklife center', 'rights': 'No known restrictions on use or reproduction.', 'source_collection': 'Traditional Music and Spoken Word Card Catalog', 'subjects': ['Canada -- Nova Scotia -- Yarmouth County -- West Pubnico', 'card catalogs'], 'title': 'The cat and her four kittens'}, 'language': ['english'], 'location': ['canada', 'yarmouth county', 'west pubnico', 'nova scotia'], 'mime_type': ['image/jpeg', 'image/jp2'], 'number': ['http://www.loc.gov/resource/afc9999005.24310.0'], 'number_former_id': ['http://www.loc.gov/resource/afc9999005.24310.0'], 'online_format': ['image'], 'original_format': ['photo, print, drawing'], 'partof': ['american folklife center', 'traditional music and spoken word card catalog', 'helen creighton national museum of canada recording project'], 'resources': [{'caption': 'Card catalog image', 'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-24310:0817/full/pct:50.0/0/default.jpg', 'paprika_resource_path': '/sets/afc/afc9999005-24310', 'url': 'https://www.loc.gov/resource/afc.afc9999005-24310/', 'version': 2}], 'shelf_id': 'AFS Number: AFS 09265 A AFS Number: AFS 09265 B', 'subject': ['card catalogs'], 'timestamp': '2024-07-10T10:52:21.066Z', 'title': 'The cat and her four kittens', 'type': ['still image'], 'url': 'https://www.loc.gov/item/afc9999005.24310/'}
# {'access_restricted': False, 'aka': ['http://www.loc.gov/item/afc9999005.27026/', 'https://hdl.loc.gov/loc.afc/afc9999005.27026', 'http://www.loc.gov/resource/afc.afc9999005-27026/'], 'campaigns': [], 'contributor': ['creighton, helen', 'mcneil, laura, mrs'], 'date': '1948-08-02', 'dates': ['1948-08-02'], 'digitized': True, 'extract_timestamp': '2024-07-10T08:38:48.185Z', 'group': ['paprika-afc'], 'hassegments': False, 'id': 'http://www.loc.gov/item/afc9999005.27026/', 'image_url': ['https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-27026:1336/full/pct:50.0/0/default.jpg', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-27026:1336/full/pct:50.0/0/default.jpg#h=456&w=756', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-27026:1336/full/pct:100.0/0/default.jpg#h=913&w=1512'], 'index': 10, 'item': {'call_number': ['AFS Number: AFS 09265 A', 'AFS Number: AFS 09265 B'], 'contributors': ['Creighton, Helen (Recordist)', 'McNeil, Laura, Mrs. (Speaker)'], 'created_published': ['West Pubnico, Nova Scotia'], 'date': '19480802', 'digital_id': ['https://hdl.loc.gov/loc.afc/afc9999005.27026'], 'format': 'still image', 'genre': ['card catalogs'], 'language': ['eng'], 'location': ['Canada -- Nova Scotia -- West Pubnico'], 'notes': ['This is a digitized catalog card, not an audio recording.', 'Statement of responsibility: Narrator: Mrs. Laura McNeil.'], 'related_items': [{'title': 'Helen Creighton National Museum of Canada Recording Project (AFC 1949/002)', 'url': 'https://lccn.loc.gov/2014655355'}], 'repository': 'american folklife center', 'rights': 'No known restrictions on use or reproduction.', 'source_collection': 'Traditional Music and Spoken Word Card Catalog', 'subjects': ['Canada -- Nova Scotia -- West Pubnico', 'card catalogs'], 'title': 'The cat and her four kittens'}, 'language': ['english'], 'location': ['canada', 'west pubnico', 'nova scotia'], 'mime_type': ['image/jpeg', 'image/jp2'], 'number': ['http://www.loc.gov/resource/afc9999005.27026.0'], 'number_former_id': ['http://www.loc.gov/resource/afc9999005.27026.0'], 'online_format': ['image'], 'original_format': ['photo, print, drawing'], 'partof': ['american folklife center', 'traditional music and spoken word card catalog', 'helen creighton national museum of canada recording project'], 'resources': [{'caption': 'Card catalog image', 'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-27026:1336/full/pct:50.0/0/default.jpg', 'paprika_resource_path': '/sets/afc/afc9999005-27026', 'url': 'https://www.loc.gov/resource/afc.afc9999005-27026/', 'version': 2}], 'shelf_id': 'AFS Number: AFS 09265 A AFS Number: AFS 09265 B', 'subject': ['card catalogs'], 'timestamp': '2024-07-10T11:02:34.687Z', 'title': 'The cat and her four kittens', 'type': ['still image'], 'url': 'https://www.loc.gov/item/afc9999005.27026/'}
# {'access_restricted': False, 'aka': ['http://www.loc.gov/jukebox/recordings/detail/id/8816', 'http://www.loc.gov/item/jukebox-61618/', 'http://www.loc.gov/resource/jukebox-61618.0/', 'http://www.loc.gov/resource/jukebox-61618.1/', 'http://www.loc.gov/resource/jukebox-61618.0', 'http://www.loc.gov/resource/jukebox-61618.1'], 'campaigns': [], 'contributor': ['confrey, zez', 'zez confrey orchestra'], 'contributor_composer': ['confrey, zez'], 'contributor_musical_group': ['zez confrey orchestra'], 'contributor_primary': ['zez confrey orchestra'], 'date': '1922-05-04', 'dates': ['1922-05-04'], 'description': ['Victor 18900. Matrix/Take: B-26259/8.'], 'digitized': True, 'extract_timestamp': '2025-08-15T12:04:45.151Z', 'group': ['nationaljukebox', 'national-jukebox'], 'hassegments': False, 'id': 'http://www.loc.gov/item/jukebox-61618/', 'image_url': ['https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/pct:12.5/0/default.jpg#h=221&w=221', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/pct:25/0/default.jpg#h=442&w=443', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/pct:50/0/default.jpg#h=884&w=886', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/pct:100/0/default.jpg#h=1769&w=1773'], 'index': 11, 'item': {'audio_type': 'Instrumental', 'contributors': ['Confrey, Zez -- Composer -- Composer', 'Confrey, Zez -- Instrumentalist -- Piano', 'Zez Confrey Orchestra -- Musical Group -- Musical Group', 'Confrey, Zez -- Leader -- Leader'], 'file_id': ['dlc_victor_18900_01_b26259_08'], 'genre': ['Ragtime, jazz, and more'], 'media_size': '10-in.', 'profile': 'jukebox', 'recording_catalog_number': '18900', 'recording_date': '1922-05-04', 'recording_label': 'Victor', 'recording_location': 'New York, New York', 'recording_matrix_number': 'B-26259 (Matrix ID)', 'recording_repository': 'Source of original recording: Recorded Sound Section, Library of Congress.', 'recording_take_id': 61618, 'recording_take_number': '8', 'rights_advisory': 'Inclusion of the recording in the National Jukebox, courtesy of Sony Music Entertainment or EMI Music', 'summary': 'Jazz/dance band'}, 'location': ['united states', 'new york'], 'mime_type': ['audio/mpeg', 'audio/wav', 'image/tif', 'image/jpeg'], 'online_format': ['audio', 'image'], 'original_format': ['sound recording'], 'other_title': ['Fox trot'], 'partof': ['recorded sound research center', 'national jukebox', 'recorded sound section, library of congress'], 'partof_repository': ['recorded sound section, library of congress'], 'resources': [{'files': 1, 'media': 'https://tile.loc.gov/streaming-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/full/0/full/default.mp3', 'url': 'https://www.loc.gov/resource/jukebox-61618.0'}, {'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dlc_victor_18900_01_b26259_08:dlc_victor_18900_01_b26259_08/full/pct:100/0/default.jpg', 'mimetype': 'image/jpeg', 'url': 'https://www.loc.gov/resource/jukebox-61618.1'}], 'shelf_id': 'Victor 18900', 'site': ['nationaljukebox'], 'subject': ['victor', 'ragtime, jazz, and more', 'instrumental'], 'subject_category': ['instrumental'], 'subject_genre': ['ragtime, jazz, and more'], 'subject_label': ['victor'], 'timestamp': '2025-08-15T12:26:13.395Z', 'title': 'Kitten on the keys', 'type': ['sound recording-musical'], 'url': 'https://www.loc.gov/item/jukebox-61618/'}
# {'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2002697127/', 'http://www.loc.gov/item/2002697127/', 'http://www.loc.gov/pictures/item/2002697127/', 'https://www.loc.gov/pictures/collection/pga/item/2002697127/', 'http://www.loc.gov/pictures/collection/pga/item/2002697127/', 'http://www.loc.gov/resource/pga.09961/', 'http://www.loc.gov/resource/cph.3b50948/', 'https://hdl.loc.gov/loc.pnp/cph.3b50948', 'http://lccn.loc.gov/2002697127', 'https://hdl.loc.gov/loc.pnp/pga.09961'], 'campaigns': [], 'contributor': ['currier & ives'], 'date': '1871-01-01', 'dates': ['1871'], 'description': ['1 print : hand-colored lithograph ; sheet 32.6 x 42.9 cm. | Print shows three white kittens on a table; the kitten on the left is drinking from a glass of "Old London Dock Port" from the bottle between the other two kittens; the kitten in the center is batting a paw at the one on the left; the kitten on the right is eating a sardine taken from an open can of "Sardines Gamus" on a low pedestal in front of it.'], 'digitized': True, 'extract_timestamp': '2021-06-28T23:55:23.014Z', 'group': ['pga', 'catalog-split-04', 'catalog', 'popular-graphic-arts', 'main-catalog-split-04', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2002697127/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/pga/09900/09961_150px.jpg#h=116&w=150', 'https://tile.loc.gov/storage-services/service/pnp/pga/09900/09961r.jpg#h=495&w=640', 'https://tile.loc.gov/storage-services/service/pnp/pga/09900/09961v.jpg#h=791&w=1024'], 'index': 12, 'item': {'call_number': 'PGA - Currier & Ives--Three jolly kittens ... (A size) [P&P]', 'contributors': ['Currier & Ives.'], 'control_number': '2002697127', 'created': '2017-08-22T05:20:23Z', 'created_published': 'New York : Published by Currier & Ives 152 Nassau St. New York, [1871]', 'created_published_date': '[1871]', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Currier%20%26%20Ives.&co=pga', 'role': '', 'title': 'Currier & Ives.'}], 'date': '[1871]', 'digital_id': ['pga 09961 //hdl.loc.gov/loc.pnp/pga.09961', 'cph 3b50948 //hdl.loc.gov/loc.pnp/cph.3b50948'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Lithographs--Hand-colored--1870-1880.&co=pga', 'title': 'Lithographs--Hand-colored--1870-1880.'}], 'genre': ['Lithographs--Hand-colored--1870-1880'], 'id': '2002697127', 'language': ['eng'], 'link': 'https://www.loc.gov/pictures/item/2002697127/', 'marc': 'https://www.loc.gov/pictures/item/2002697127/marc/', 'medium': ['1 print : hand-colored lithograph ; sheet 32.6 x 42.9 cm.'], 'medium_brief': '1 print :', 'mediums': ['1 print : hand-colored lithograph ; sheet 32.6 x 42.9 cm.'], 'modified': '2017-08-22T05:20:23Z', 'notes': ['Title from item.', 'Publication date based on copyright statement on item.', 'Currier & Ives : a catalogue raisonné / compiled by Gale Research. Detroit, MI : Gale Research, c1983, no. 6514', 'Forms part of: Popular graphic art print filing series (Library of Congress).'], 'number_former_id': ['https://www.loc.gov/item/2002697127', 'https://www.loc.gov/item/12639985'], 'other_control_numbers': ['12639985'], 'part_of': 'Popular graphic art print filing series (Library of Congress)', 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-pga-09961 (digital file from original print)\nLC-USZC2-3074 (color film copy slide)', 'resource_links': ['//hdl.loc.gov/loc.pnp/pga.09961', '//hdl.loc.gov/loc.pnp/cph.3b50948'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/pga/09900/09961_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/pga/09900/09961r.jpg', 'sort_date': '1871', 'source_collection' ...
# ...
# {'access_restricted': False, 'aka': ['http://www.loc.gov/item/afc9999005.12471/', 'https://hdl.loc.gov/loc.afc/afc9999005.12471', 'http://www.loc.gov/resource/afc.afc9999005-12471/'], 'campaigns': [], 'contributor': ['oriet, frenchy', 'cowell, sidney robertson'], 'date': '1938-12', 'dates': ['1938-12'], 'digitized': True, 'extract_timestamp': '2024-07-10T07:13:35.843Z', 'group': ['paprika-afc'], 'hassegments': False, 'id': 'http://www.loc.gov/item/afc9999005.12471/', 'image_url': ['https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-12471:0758/full/pct:50.0/0/default.jpg', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-12471:0758/full/pct:50.0/0/default.jpg#h=450&w=748', 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-12471:0758/full/pct:100.0/0/default.jpg#h=901&w=1497'], 'index': 22, 'item': {'call_number': ['AFS Number: AFS 04208 B01'], 'contributors': ['Cowell, Sidney Robertson (Recordist)', 'Oriet, Frenchy (Performer)'], 'created_published': ['Central Valley, California'], 'date': '19381200', 'digital_id': ['https://hdl.loc.gov/loc.afc/afc9999005.12471'], 'format': 'still image', 'genre': ['card catalogs'], 'language': ['eng'], 'location': ['United States of America -- California -- Central Valley'], 'notes': ['This is a digitized catalog card, not an audio recording.', 'Instrument: Harmonica (mouth organ)', 'Statement of responsibility: Played by Frenchy Oriet on harmonica.'], 'related_items': [{'title': 'W.P.A. California Folk Music Project Collection (AFC 1940/001)', 'url': 'https://lccn.loc.gov/2008700333'}], 'repository': 'american folklife center', 'rights': 'No known restrictions on use or reproduction.', 'source_collection': 'Traditional Music and Spoken Word Card Catalog', 'subjects': ['United States of America -- California -- Central Valley', 'card catalogs'], 'title': 'Feeding his kittens on baked corn bread'}, 'language': ['english'], 'location': ['united states', 'california', 'central valley'], 'mime_type': ['image/jpeg', 'image/jp2'], 'number': ['http://www.loc.gov/resource/afc9999005.12471.0'], 'number_former_id': ['http://www.loc.gov/resource/afc9999005.12471.0'], 'online_format': ['image'], 'original_format': ['photo, print, drawing'], 'partof': ['american folklife center', 'traditional music and spoken word card catalog', 'w.p.a. california folk music project collection'], 'resources': [{'caption': 'Card catalog image', 'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-12471:0758/full/pct:50.0/0/default.jpg', 'paprika_resource_path': '/sets/afc/afc9999005-12471', 'url': 'https://www.loc.gov/resource/afc.afc9999005-12471/', 'version': 2}], 'shelf_id': 'AFS Number: AFS 04208 B01', 'subject': ['card catalogs'], 'timestamp': '2024-07-10T10:10:30.711Z', 'title': 'Feeding his kittens on baked corn bread', 'type': ['still image'], 'url': 'https://www.loc.gov/item/afc9999005.12471/'}
# {'access_restricted': False, 'aka': ['http://lccn.loc.gov/2023835671', 'http://www.loc.gov/item/2023835671/', 'http://www.loc.gov/resource/music.mussm-sm1880-04831/', 'https://hdl.loc.gov/loc.music/sm1880.04831'], 'campaigns': [], 'contributor': ['leslie, herbert'], 'date': '1880', 'dates': ['1880'], 'description': ['Record created through migration from the Performing Arts Encyclopedia Database.'], 'digitized': True, 'extract_timestamp': '2025-06-18T07:01:40.668Z', 'group': ['paprika-music', 'catalog-split-05', 'catalog', 'main-catalog-split-05'], 'hassegments': True, 'id': 'http://www.loc.gov/item/2023835671/', 'image_url': ['https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:6.25/0/default.jpg', 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:6.25/0/default.jpg#h=376&w=291', 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:12.5/0/default.jpg#h=753&w=583', 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:25.0/0/default.jpg#h=1507&w=1167', 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:50.0/0/default.jpg#h=3014&w=2334', 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:100.0/0/default.jpg#h=6029&w=4669'], 'index': 23, 'item': {'contributors': ['Leslie, Herbert'], 'created_published': ['Boston : Russell, G. D., 1880.'], 'date': '1880', 'format': ['notated music'], 'genre': ['Schottisches (Music)'], 'medium': ['1 online resource (1 score)'], 'notes': ['Record created through migration from the Performing Arts Encyclopedia Database.'], 'number_former_id': ['https://www.loc.gov/item/2023835671', 'https://www.loc.gov/item/sm1880.04831'], 'repository': ['c-Music Electronic resource'], 'subjects': ['Piano music', 'Schottisches'], 'title': 'Precious kitten'}, 'mime_type': ['image/jpeg', 'application/pdf', 'image/jp2'], 'number': ['http://www.loc.gov/item/sm1880.04831', 'http://www.loc.gov/resource/sm1880.04831.0', '2023835671', '2023-12-18t16:50:09', 'http://www.loc.gov/item/2023835671', 'online resource'], 'number_carrier_type': ['online resource'], 'number_former_id': ['http://www.loc.gov/resource/sm1880.04831.0', 'http://www.loc.gov/item/2023835671', 'http://www.loc.gov/item/sm1880.04831'], 'number_lccn': ['2023835671'], 'number_source_modified': ['2023-12-18t16:50:09'], 'online_format': ['image', 'pdf'], 'original_format': ['notated music'], 'partof': ['music for the nation: american sheet music, ca. 1870-1885', 'catalog', 'music division'], 'resources': [{'files': 4, 'image': 'https://tile.loc.gov/image-services/iiif/public:music:mussm-sm1880-04831:001/full/pct:6.25/0/default.jpg', 'paprika_resource_path': '/sets/music/mussm-sm1880-04831', 'pdf': 'https://tile.loc.gov/storage-services/public/music/mussm-sm1880-04831/mussm-sm1880-04831.pdf', 'schemaVersion': 'v1', 'search': 'https://www.loc.gov/search/?fa=segmentof:music.mussm-sm1880-04831/&fo=json&q=kittens&st=gallery', 'segments': 4, 'url': 'https://www.loc.gov/resource/music.mussm-sm1880-04831/', 'version': 4}], 'segments': [{'count': 4, 'link': 'https://www.loc.gov/search/?fa=segmentof:music.mussm-sm1880-04831/&fo=json&q=kittens&st=gallery', 'url': 'https://www.loc.gov/resource/music.mussm-sm1880-04831/'}], 'shelf_id': 'https://repo.loc.gov/access/public/music/mussm-sm1880-04831/.resource.json', 'site': ['catalog'], 'subject': ['schottisches', 'piano music', 'schottisches (music)'], 'timestamp': '2025-06-18T09:35:09.987Z', 'title': 'Precious kitten', 'type': ['notated music'], 'url': 'https://www.loc.gov/item/2023835671/'}
# {'access_restricted': False, 'aka': ['http://www.loc.gov/jukebox/recordings/detail/id/5092', 'http://www.loc.gov/item/jukebox-191416/', 'http://www.loc.gov/resource/jukebox-191416.0/', 'http://www.loc.gov/resource/jukebox-191416.1/', 'http://www.loc.gov/resource/jukebox-191416.0', 'http://www.loc.gov/resource/jukebox-191416.1'], 'campaigns': [], 'contributor': ['porter, steve'], 'contributor_primary': ['porter, steve'], 'contributor_vocalist': ['porter, steve'], 'date': '1901-06-12', 'dates': ['1901-06-12'], 'description': ['Victor 3468. Matrix/Take: [Pre-matrix B-]3468/1.'], 'digitized': True, 'extract_timestamp': '2025-08-15T12:05:23.628Z', 'group': ['nationaljukebox', 'national-jukebox'], 'hassegments': False, 'id': 'http://www.loc.gov/item/jukebox-191416/', 'image_url': ['https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/pct:12.5/0/default.jpg#h=280&w=279', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/pct:25/0/default.jpg#h=561&w=559', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/pct:50/0/default.jpg#h=1123&w=1118', 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/pct:100/0/default.jpg#h=2246&w=2236'], 'index': 24, 'item': {'audio_type': 'Vocal', 'contributors': ['Porter, Steve -- Vocalist -- Baritone Vocal'], 'file_id': ['dgio_victor_3468_01_b3468_01'], 'genre': ['Popular music'], 'language': 'English', 'media_size': '10-in.', 'profile': 'jukebox', 'recording_catalog_number': '3468', 'recording_date': '1901-06-12', 'recording_label': 'Victor', 'recording_location': 'Camden, New Jersey [unconfirmed]', 'recording_matrix_number': '[Pre-matrix B-]3468 (Matrix ID)', 'recording_repository': 'Source of original recording: Giovannoni/Lynch Collection (private collection).', 'recording_take_id': 191416, 'recording_take_number': '1', 'rights_advisory': 'Inclusion of the recording in the National Jukebox, courtesy of Sony Music Entertainment or EMI Music', 'summary': 'Male vocal solo'}, 'language': ['english'], 'location': ['united states', 'new jersey', 'camden'], 'mime_type': ['audio/mpeg', 'audio/wav', 'image/tif', 'image/jpeg'], 'online_format': ['audio', 'image'], 'original_format': ['sound recording'], 'partof': ['recorded sound research center', 'national jukebox', 'giovannoni/lynch collection (private collection)'], 'partof_repository': ['giovannoni/lynch collection (private collection)'], 'resources': [{'files': 1, 'media': 'https://tile.loc.gov/streaming-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/full/0/full/default.mp3', 'url': 'https://www.loc.gov/resource/jukebox-191416.0'}, {'files': 1, 'image': 'https://tile.loc.gov/image-services/iiif/service:mbrsrs:mbrsjukebox:dgio_victor_3468_01_b3468_01:dgio_victor_3468_01_b3468_01/full/pct:100/0/default.jpg', 'mimetype': 'image/jpeg', 'url': 'https://www.loc.gov/resource/jukebox-191416.1'}], 'shelf_id': 'Victor 3468', 'site': ['nationaljukebox'], 'subject': ['victor', 'vocal', 'popular music'], 'subject_category': ['vocal'], 'subject_genre': ['popular music'], 'subject_label': ['victor'], 'timestamp': '2025-08-15T12:19:26.457Z', 'title': 'An armful of kittens and a cat', 'type': ['sound recording-musical'], 'url': 'https://www.loc.gov/item/jukebox-191416/'}
# {'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2002697129/', 'http://www.loc.gov/item/2002697129/', 'http://www.loc.gov/pictures/item/2002697129/', 'https://www.loc.gov/pictures/collection/pga/item/2002697129/', 'http://www.loc.gov/pictures/collection/pga/item/2002697129/', 'http://www.loc.gov/resource/pga.05046/', 'https://hdl.loc.gov/loc.pnp/pga.05046', 'http://lccn.loc.gov/2002697129'], 'campaigns': [], 'contributor': ['stark, otto', 'currier & ives'], 'date': '1879-01-01', 'dates': ['1879'], 'description': ['1 print : lithograph, hand-colored.'], 'digitized': True, 'extract_timestamp': '2021-06-28T22:56:28.339Z', 'group': ['pga', 'catalog-split-06', 'catalog', 'popular-graphic-arts', 'main-catalog-split-06', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2002697129/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046_150px.jpg#h=122&w=150', 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046t.gif#h=122&w=150', 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046r.jpg#h=522&w=640', 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046v.jpg#h=835&w=1024'], 'index': 25, 'item': {'call_number': 'PGA - Currier & Ives--Three white kittens: peace (B size) [P&P]', 'contributor_names': ['Stark, Otto, 1859-1926, artist '], 'contributors': ['Currier & Ives.', 'Stark, Otto, 1859-1926, artist.'], 'control_number': '2002697129', 'created': '2019-10-15T05:54:50Z', 'created_published': 'New York : Published by Currier & Ives, [between 1879 and 1907].', 'created_published_date': '[between 1879 and 1907].', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Currier%20%26%20Ives.&co=pga', 'role': '', 'title': 'Currier & Ives.'}, {'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Stark%2C%20Otto%2C%201859-1926&co=pga', 'role': 'artist', 'title': 'Stark, Otto, 1859-1926'}], 'date': '[between 1879 and 1907].', 'digital_id': ['pga 05046 //hdl.loc.gov/loc.pnp/pga.05046'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Lithographs--Hand-colored--1870-1910.&co=pga', 'title': 'Lithographs--Hand-colored--1870-1910.'}], 'genre': ['Lithographs--Hand-colored--1870-1910'], 'id': '2002697129', 'language': ['eng'], 'link': 'https://www.loc.gov/pictures/item/2002697129/', 'marc': 'https://www.loc.gov/pictures/item/2002697129/marc/', 'medium': ['1 print : lithograph, hand-colored.'], 'medium_brief': '1 print :', 'mediums': ['1 print : lithograph, hand-colored.'], 'modified': '2019-10-15T05:54:51Z', 'notes': ['Currier & Ives : a catalogue raisonné / compiled by Gale Research. Detroit, MI : Gale Research, c1983, no. 6522'], 'number_former_id': ['https://www.loc.gov/item/2002697129', 'https://www.loc.gov/item/12639993'], 'other_control_numbers': ['12639993'], 'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print', 'reproduction_number': 'LC-DIG-pga-05046 (digital file from original item)', 'resource_links': ['//hdl.loc.gov/loc.pnp/pga.05046'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046r.jpg', 'sort_date': '1879', 'source_created': '2002-01-09T00:00:00Z', 'source_modified': '2019-10-09T09:40:44Z', 'stmt_of_responsibility': 'O.S. sc.', 'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/pga/05000/05046_150px.jpg', 'title': 'The three white kittens: peace'}, 'language': ['english'], 'mime_type': ['image/gif', 'image/jpg', 'image/tif'], 'number': ['2002697129', '2019-10-09t09:40:44', 'http://www.loc.gov/item/2002697129', 'http://www.loc.gov/item/12639993'], 'number_former_id': ['http://www.loc.gov/it ...

# %%
for item in data['results']:
    print(item['title'])
# Out:
# [Kittens]
# Cat and kittens
# Kitten on the keys
# [Mother cat and kittens]
# The sick kitten
# Boys with kitten
# [Boys with kitten]
# Girl with kitten
# The cat and her four kittens
# The cat and her four kittens
# Kitten on the keys
# The three jolly kittens - at the feast
# Two jolly kittens at a feast
# The three jolly kittens - after the feast
# Scrap and his kitten
# [Girl with sleeping kitten]
# Calvin Coolidge [with kitten]
# [Domestic cat nursing kittens]
# [Kitten's party (child study)]
# Ten kittens,
# Upper - a cat and her kittens; Lower - Princess Gray Paws, a Persian kitten
# Feeding his kittens on baked corn bread
# Precious kitten
# An armful of kittens and a cat
# The three white kittens: peace

# %%
print(len(data['results']))
# Out:
# 25

# %% [markdown]
# When compared with the html version here, notice that that page also has 25 results!
#
# See https://www.loc.gov/photos/?fa=online-format:image&q=kittens
#
# Is it possible to extract each result into its own file?

# %%
# block testing an extaction of each result into a separate file

data = json.loads(r.text)

#grab the images into a list
kittensList = data['results']
print(len(kittensList))
# Out:
# 25

# %%
fname = 'kitten-result-'
format = '.json'
n = 0 

for item in kittensList:
    n = n + 1
    file = fname + str(n) + format
#    print(item)
    with open(file, 'w') as f:
        f.write(json.dumps(item, indent = 2))#, f, encoding='utf-8', sort_keys=True)
        print('wrote',file)
print('wrote',n,'files!')
# Out:
# wrote kitten-result-1.json
# wrote kitten-result-2.json
# wrote kitten-result-3.json
# wrote kitten-result-4.json
# wrote kitten-result-5.json
# wrote kitten-result-6.json
# wrote kitten-result-7.json
# wrote kitten-result-8.json
# wrote kitten-result-9.json
# wrote kitten-result-10.json
# wrote kitten-result-11.json
# wrote kitten-result-12.json
# wrote kitten-result-13.json
# wrote kitten-result-14.json
# wrote kitten-result-15.json
# wrote kitten-result-16.json
# wrote kitten-result-17.json
# wrote kitten-result-18.json
# wrote kitten-result-19.json
# wrote kitten-result-20.json
# wrote kitten-result-21.json
# wrote kitten-result-22.json
# wrote kitten-result-23.json
# wrote kitten-result-24.json
# wrote kitten-result-25.json
# wrote 25 files!

# %% [markdown]
# How could we extract the image URLs?

# %%
for key in kittensList[0]:
    print(key)
# Out:
# access_restricted
# aka
# campaigns
# contributor
# date
# dates
# description
# digitized
# extract_timestamp
# group
# hassegments
# id
# image_url
# index
# item
# language
# location
# location_country
# mime_type
# number
# number_former_id
# number_lccn
# number_source_modified
# online_format
# original_format
# partof
# related
# reproductions
# resources
# shelf_id
# site
# subject
# timestamp
# title
# type
# unrestricted
# url

# %% [markdown]
# Note the `url` key in the above list of keys. That seems like a likely place to find a URL!

# %%
for kitten in kittensList:
    print(kitten['url'])
# Out:
# https://www.loc.gov/item/2016892679/
# https://www.loc.gov/item/2017650796/
# https://www.loc.gov/item/jukebox-668708/
# https://www.loc.gov/item/2013646722/
# https://www.loc.gov/item/2022653071/
# https://www.loc.gov/item/2016796464/
# https://www.loc.gov/item/2016816441/
# https://www.loc.gov/item/2016817090/
# https://www.loc.gov/item/afc9999005.24310/
# https://www.loc.gov/item/afc9999005.27026/
# https://www.loc.gov/item/jukebox-61618/
# https://www.loc.gov/item/2002697127/
# https://www.loc.gov/item/89708607/
# https://www.loc.gov/item/2002697126/
# https://www.loc.gov/item/2005681032/
# https://www.loc.gov/item/2022652300/
# https://www.loc.gov/item/2014717546/
# https://www.loc.gov/item/2008660988/
# https://www.loc.gov/item/2002706499/
# https://www.loc.gov/item/20002503/
# https://www.loc.gov/item/2022653887/
# https://www.loc.gov/item/afc9999005.12471/
# https://www.loc.gov/item/2023835671/
# https://www.loc.gov/item/jukebox-191416/
# https://www.loc.gov/item/2002697129/

# %% [markdown]
# ## Lab Questions
#
# See the course activities page for the lab questions.
