# %% [markdown]
# # Extract and Transform OAI-PMH
#
# This notebook provides starter Python code for retrieving and transforming OAI-PMH metadata.
#
# It starts with a sample object from Wayne State University's collections: https://cdm17409.contentdm.oclc.org/digital/collection/rencen/id/315/rec/3.
#
# ## Endpoint formulation
#
# The OAI-PMH endpoint is found by locating the base URL for the repository,
# then appending `oai` and the API action is activated by the `oai.php` script.
# For the above, then, the OAI-PMH endpoint is:
#
# `https://cdm17409.contentdm.oclc.org/oai/oai.php`
#
# ### Item metadata URL formulation:
#
# OAI-PMH creates a standard object identifier, which places the object within a repository, an item set (collection), and a numerical identifier. Various elements of the identifier are separated by a colon (`:`), but note the slash (`/`) that is present in the object ID. A possible formula is as follows (where the plus (`+`) indicates concatenation of the string):
#
# `oai: + repo_ID + : + set/item_ID`
#
# Thus, there are three elements: a designation of the `oai` as a main namespace,
# a repository identifier, and an object identifier (that includes set designation).
#
# A sample identifier (for the above item) would be: `oai:cdm17409.contentdm.oclc.org:rencen/3`

# %%
import requests
from lxml import etree

# %% [markdown]
# ## Get the data for one item
#
# This is mostly for testing and illustration.
# By requesting the data for one item, you can look at the data structures and items, which is important for reference.
# The following code retrieves item meatdata for item `3` in the `rencen` dataset from the above OAI endpoint.
#
# **Item information:**
#
# - Item set: `rencen`
# - Item ID (within set): `3`
# - goal URL for request: https://cdm17409.contentdm.oclc.org/oai/oai.php?verb=GetRecord&identifier=oai:cdm17409.contentdm.oclc.org:rencen/3&metadataPrefix=oai_dc

# %%
set = 'rencen'
item_ID = '3'
endpoint = 'https://cdm17409.contentdm.oclc.org/oai/oai.php'
verb = 'GetRecord'
repo_ID = 'cdm17409.contentdm.oclc.org'

# %%
parameters = {
    'identifier': 'oai:' + repo_ID + ':' + set + '/' + item_ID,
    'verb': verb,
    'metadataPrefix': 'oai_dc'
}

# %%
# make the request
item = requests.get(endpoint, params=parameters)

# %%
item.url
# Out:
# 'https://cdm17409.contentdm.oclc.org/oai/oai.php?identifier=oai%3Acdm17409.contentdm.oclc.org%3Arencen%2F3&verb=GetRecord&metadataPrefix=oai_dc'

# %%
r_metadata = etree.fromstring(item.content)

# %%
for element in r_metadata:
    print(element.tag, element.attrib)
# Out:
# {http://www.openarchives.org/OAI/2.0/}responseDate {}
# {http://www.openarchives.org/OAI/2.0/}request {'verb': 'GetRecord', 'identifier': 'oai:cdm17409.contentdm.oclc.org:rencen/3', 'metadataPrefix': 'oai_dc'}
# {http://www.openarchives.org/OAI/2.0/}GetRecord {}

# %%
# find the data:
ns = {
    'oai': 'http://www.openarchives.org/OAI/2.0/'
}

metadata = r_metadata.findall('.//oai:metadata', ns)

for item in metadata:
    print(etree.tostring(item, encoding='utf-8').decode('utf-8'))
# Out:
# <metadata xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# <oai_dc:dc xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">
# <dc:title>View of the atrium in the completed Renaissance Center.</dc:title>
# <dc:description>Image of the atrium within the Renaissance Center, looking up at a large concrete structure. Trees, plants, and people can be seen in this picture of a restaurant.</dc:description>
# <dc:identifier>rencen_03e</dc:identifier>
# <dc:date>1977</dc:date>
# <dc:type>still image</dc:type>
# <dc:format>photographs</dc:format>
# <dc:subject>Renaissance Center (Detroit, Mich.)</dc:subject>
# <dc:coverage>Detroit, Michigan</dc:coverage>
# <dc:coverage>1970s</dc:coverage>
# <dc:relation>Building the Detroit Renaissance Center</dc:relation>
# <dc:rights>Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.</dc:rights>
# <dc:date>1977</dc:date>
# <dc:identifier>http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/3</dc:identifier></oai_dc:dc>
# </metadata>

# %% [markdown]
# ## Extract IDs for all items in the set
#
# The OAI-PMH protocol allows for the retrieval of information about all
# items in a set, using the `ListIdentifiers` verb.
#
# For large sets, usually over 200 items, the responses are controlled by
# a paginated response. The next page can be requesting using the `resumptionToken`
# provided at the end of the response.
# See https://gist.github.com/rlskoeser/880a6f9f20bbaf9202fb for ideas on how to use the Token.

# %%
endpoint = 'https://cdm17409.contentdm.oclc.org/oai/oai.php'

set = 'rencen'
verb = 'ListIdentifiers'
resumptionToken = None

# %%
# jajohnst's initial code - close but not really working
# doesn't handle the while loop exit correctly,
# doesn't correctly update the 
def get_oai_set_ids(oai_url, oai_set=None, verb='ListIdentifiers'):
    '''This function takes an endpoint URL for an OAI-PMH repository
    and then requests all of the items in a given set. If no set is provided,
    then the set is assumed to be None. For large sets, the function will 
    use the response's resmptionToken.
    
    Returns a list of identifiers for the set.'''

    identifiers = list()

    parameters = {
        'verb': verb,
        'metadataPrefix': 'oai_dc'
        }
    if oai_set is not None:
        parameters['set'] = oai_set

    # make the requests
    r = requests.get(oai_url, params=parameters)

    # parse the responses
    response_xml = etree.fromstring(r.content)

    # get the Token
    resumptionToken = response_xml.find('.//{http://www.openarchives.org/OAI/2.0/}resumptionToken').text
    print('...',resumptionToken)

    while resumptionToken:
        for identifier in response_xml.iterfind('.//{http://www.openarchives.org/OAI/2.0/}identifier'):
            identifiers.append(identifier.text)

'''
    # if resumptionToken, recurse
    if resumptionToken is not None:
        # get the identifiers
        for identifier in response_xml.iterfind('.//{http://www.openarchives.org/OAI/2.0/}identifier'):
            identifiers.append(identifier.text)
        parameters['resumptionToken'] = resumptionToken

    # if no resumptionToken, just get the identifiers
    else:
        for identifier in response_xml.iterfind('.//{http://www.openarchives.org/OAI/2.0/}identifier'):
            identifiers.append(identifier.text)
'''            
    # record and return the identifiers
    return identifiers

# %%
# changed and updated by ClaudeAI to add an exit function for the while loop
def get_oai_set_ids(oai_url, oai_set=None, verb='ListIdentifiers'):
    '''This function takes an endpoint URL for an OAI-PMH repository
    and then requests all of the items in a given set. If no set is provided,
    then the set is assumed to be None. For large sets, the function will 
    use the response's resumptionToken.
    
    Returns a list of identifiers for the set.'''

    identifiers = list()

    parameters = {
        'verb': verb,
        'metadataPrefix': 'oai_dc'
    }
    if oai_set is not None:
        parameters['set'] = oai_set

    # make the initial request
    r = requests.get(oai_url, params=parameters)
    print('initial request ...',r.url)
    response_xml = etree.fromstring(r.content)

    # process first response
    for identifier in response_xml.iterfind('.//{http://www.openarchives.org/OAI/2.0/}identifier'):
        identifiers.append(identifier.text)
    
    # get the initial resumptionToken
    resumption_token_element = response_xml.find('.//{http://www.openarchives.org/OAI/2.0/}resumptionToken')
    # handle None responses, if no resumptionToken
    resumptionToken = resumption_token_element.text if resumption_token_element is not None else None

    while resumptionToken:
        # update parameters with resumptionToken
        parameters = {
            'verb': verb,
            'resumptionToken': resumptionToken
        }

        # make the next request
        r = requests.get(oai_url, params=parameters)
        print('requesting ...',resumptionToken)
        response_xml = etree.fromstring(r.content)

        # process the response
        for identifier in response_xml.iterfind('.//{http://www.openarchives.org/OAI/2.0/}identifier'):
            identifiers.append(identifier.text)

        # get the next resumptionToken
        resumption_token_element = response_xml.find('.//{http://www.openarchives.org/OAI/2.0/}resumptionToken')
        
        # If no resumption token, set to None to exit the loop
        resumptionToken = resumption_token_element.text if resumption_token_element is not None else None

    # return the identifiers
    return identifiers

# %%
identifiers = get_oai_set_ids(endpoint, oai_set='rencen')
# Out:
# initial request ... https://cdm17409.contentdm.oclc.org/oai/oai.php?verb=ListIdentifiers&metadataPrefix=oai_dc&set=rencen
# requesting ... rencen:200:rencen:0000-00-00:9999-99-99:oai_dc

# %%
len(identifiers)
# Out:
# 323

# %% [markdown]
# Looks like it works!

# %% [markdown]
# ## Request metadata for each of the items
#
# This function uses the identifiers list to request the full information for each item.
# Then, that information is entered into a CSV or JSON.

# %%
def oai_get_item_info_from_list(endpoint, identifiers, verb='GetRecord', metadataPrefix='oai_dc'):
    '''Function to get full item metadata for a list of supplied identifiers.
    Requires lxml to parse XML responses.
    Supply: 
      - endpoint (a valid OAI-PMH endpoint URL)
      - identifiers (python list)
      - verb defaults to 'GetRecord' but another 'verb' argument may be provided
      - metadataPrefix defaults to 'oai_dc' but may be provided

    Returns data in a dictionary that can be converted into CSV or JSON.'''

    set_metadata_dict = dict()

    parameters = {
        'verb': verb,
        'metadataPrefix': metadataPrefix
    }

    # namespaces for XML parsing
    ns = {
        'oai': 'http://www.openarchives.org/OAI/2.0/',
        'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/',
        'dc': 'http://purl.org/dc/elements/1.1/'
    }

    # make requests
    for identifier in identifiers:
        parameters['identifier'] = identifier
        r = requests.get(endpoint, params=parameters)
        print(f"Retrieving ... {identifier}")
        
        # Check if request was successful
        if r.status_code != 200:
            print(f"Error retrieving {identifier}: Status code {r.status_code}")
            continue

        try:
            response_xml = etree.fromstring(r.content)
            
            # Find the metadata section
            item_data = response_xml.find('.//oai:metadata', namespaces=ns)
            
            if item_data is None:
                print(f"No metadata found for {identifier}")
                continue

            # Create a dictionary for this specific identifier
            item_metadata = {}
            
            # Iterate through all DC fields
            for dc_field in item_data.iterfind('.//dc:*', namespaces=ns):
                # Extract the local name (without namespace)
                local_name = etree.QName(dc_field.tag).localname
                
                # Create dcterms-prefixed key
                key = f"dcterms:{local_name}"
                
                # Handle multiple values for the same field
                if key in item_metadata:
                    # If the key already exists, convert to list or append
                    if isinstance(item_metadata[key], list):
                        item_metadata[key].append(dc_field.text)
                    else:
                        item_metadata[key] = [item_metadata[key], dc_field.text]
                else:
                    item_metadata[key] = dc_field.text
            
            # Store the metadata for this identifier
            set_metadata_dict[identifier] = item_metadata

        except etree.XMLSyntaxError:
            print(f"XML parsing error for {identifier}")
        except Exception as e:
            print(f"Unexpected error processing {identifier}: {e}")

    return set_metadata_dict

# %%
oai_get_item_info_from_list(endpoint=endpoint, identifiers=identifiers[:5])
# Out:
# {'oai:cdm17409.contentdm.oclc.org:rencen/0': {'dcterms:title': 'View of ongoing construction of the Renaissance Center towers',
#   'dcterms:description': 'Image of the building progress on two of the four towers of the Renaissance Center.  Construction equipment is clearing visible.',
#   'dcterms:identifier': ['rencen_05b',
#    'http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/0'],
#   'dcterms:date': ['1973', '1973'],
#   'dcterms:type': 'still image',
#   'dcterms:format': 'photographs',
#   'dcterms:subject': 'Construction industry; Construction equipment; Scaffolding; Cranes, derricks, etc.; Renaissance Center (Detroit, Mich.)',
#   'dcterms:coverage': ['Detroit, Michigan', '1970s'],
#   'dcterms:relation': 'Building the Detroit Renaissance Center',
#   'dcterms:rights': 'Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.'},
#  'oai:cdm17409.contentdm.oclc.org:rencen/1': {'dcterms:title': 'View of the ground floor atrium in the completed Renaissance Center.',
#   'dcterms:description': 'Image of the atrium within the Renaissance Center, looking down from the second floor. Note the concrete supports and components that make up portions of this building.',
#   'dcterms:identifier': ['rencen_03d',
#    'http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/1'],
#   'dcterms:date': ['1977', '1977'],
#   'dcterms:type': 'still image',
#   'dcterms:format': 'photographs',
#   'dcterms:subject': 'Renaissance Center (Detroit, Mich.)',
#   'dcterms:coverage': ['Detroit, Michigan', '1970s'],
#   'dcterms:relation': 'Building the Detroit Renaissance Center',
#   'dcterms:rights': 'Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.'},
#  'oai:cdm17409.contentdm.oclc.org:rencen/2': {'dcterms:title': 'The Renaissance Center towers as viewed from Jefferson Avenue',
#   'dcterms:description': 'Image of the partially built Renaissance Center towers during construction.  This photograph was taken from Jefferson Avenue and derricks and scaffolding are visible.',
#   'dcterms:identifier': ['rencen_09f',
#    'http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/2'],
#   'dcterms:date': ['1973', '1973'],
#   'dcterms:type': 'still image',
#   'dcterms:format': 'photographs',
#   'dcterms:subject': 'Construction industry; Construction equipment; Scaffolding; Cranes, derricks, etc.; Renaissance Center (Detroit, Mich.)',
#   'dcterms:coverage': ['Detroit, Michigan', '1970s'],
#   'dcterms:relation': 'Building the Detroit Renaissance Center',
#   'dcterms:rights': 'Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.'},
#  'oai:cdm17409.contentdm.oclc.org:rencen/3': {'dcterms:title': 'View of the atrium in the completed Renaissance Center.',
#   'dcterms:description': 'Image of the atrium within the Renaissance Center, looking up at a large concrete structure. Trees, plants, and people can be seen in this picture of a restaurant.',
#   'dcterms:identifier': ['rencen_03e',
#    'http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/3'],
#   'dcterms:date': ['1977', '1977'],
#   'dcterms:type': 'still image',
#   'dcterms:format': 'photographs',
#   'dcterms:subject': 'Renaissance Center (Detroit, Mich.)',
#   'dcterms:coverage': ['Detroit, Michigan', '1970s'],
#   'dcterms:relation': 'Building the Detroit Renaissance Center',
#   'dcterms:rights': 'Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.'},
#  'oai:cdm17409.contentdm.oclc.org:rencen/4': {'dcterms:title': 'View of an unidentified building near the Renaissance Center construction site',
#   'dcterms:description': 'Image of an unidentified building in the vicinity of the Renaissance Center construction site.',
#   'dcterms:identifier': ['rencen_18a',
#    'http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/4'],
#   'dcterms:date': ['1973', '1973'],
#   'dcterms:type': 'still image',
#   'dcterms:format': 'photographs',
#   'dcterms:subject': 'Construction industry; Renaissance Center (Detroit, Mich.)',
#   'dcterms:coverage': ['Detroit, Michigan', '1970s'],
#   'dcterms:relation': 'Building the Detroit Renaissance Center',
#   'dcterms:rights': 'Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.'}}

# %%
rencen_set_info = oai_get_item_info_from_list(endpoint=endpoint, identifiers=identifiers)
# Out:
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/0
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/1
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/2
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/3
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/4
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/5
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/6
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/7
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/8
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/9
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/10
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/11
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/12
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/13
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/14
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/15
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/16
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/17
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/18
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/19
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/20
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/21
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/22
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/23
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/24
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/25
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/26
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/27
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/28
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/29
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/30
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/31
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/32
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/33
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/34
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/35
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/36
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/37
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/38
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/39
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/40
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/41
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/42
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/43
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/44
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/45
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/46
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/47
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/48
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/49
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/50
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/51
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/52
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/53
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/54
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/55
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/56
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/57
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/58
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/59
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/60
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/61
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/62
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/63
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/64
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/65
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/66
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/67
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/68
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/69
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/70
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/71
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/72
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/73
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/74
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/75
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/76
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/77
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/78
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/79
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/80
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/81
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/82
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/83
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/84
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/85
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/86
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/87
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/88
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/89
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/90
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/91
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/92
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/93
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/94
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/95
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/96
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/97
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/98
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/99
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/100
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/101
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/102
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/103
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/104
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/105
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/106
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/107
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/108
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/109
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/110
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/111
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/112
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/113
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/114
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/115
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/116
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/117
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/118
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/119
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/120
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/121
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/122
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/123
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/124
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/125
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/126
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/127
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/128
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/129
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/130
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/131
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/132
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/133
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/134
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/135
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/136
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/137
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/138
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/139
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/140
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/141
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/142
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/143
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/144
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/145
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/146
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/147
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/148
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/149
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/150
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/151
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/152
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/153
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/154
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/155
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/156
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/157
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/158
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/159
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/160
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/161
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/162
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/163
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/164
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/165
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/166
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/167
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/168
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/169
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/170
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/171
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/172
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/173
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/174
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/175
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/176
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/177
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/178
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/179
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/180
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/181
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/182
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/183
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/184
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/185
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/186
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/187
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/188
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/189
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/190
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/191
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/192
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/193
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/194
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/195
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/196
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/197
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/198
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/199
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/200
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/201
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/202
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/203
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/204
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/205
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/206
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/207
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/208
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/209
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/210
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/211
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/212
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/213
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/214
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/215
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/216
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/217
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/218
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/219
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/220
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/221
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/222
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/223
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/224
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/225
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/226
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/227
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/228
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/229
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/230
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/231
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/232
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/233
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/234
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/235
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/236
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/237
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/238
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/239
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/240
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/241
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/242
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/243
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/244
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/245
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/246
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/247
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/248
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/249
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/250
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/251
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/252
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/253
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/254
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/255
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/256
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/257
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/258
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/259
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/260
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/261
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/262
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/263
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/264
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/265
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/266
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/267
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/268
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/269
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/270
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/271
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/272
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/273
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/274
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/275
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/276
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/277
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/278
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/279
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/280
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/281
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/282
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/283
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/284
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/285
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/286
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/287
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/288
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/289
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/290
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/291
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/292
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/293
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/294
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/295
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/296
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/297
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/298
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/299
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/300
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/301
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/302
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/303
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/304
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/305
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/306
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/307
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/308
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/309
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/310
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/311
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/312
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/313
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/314
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/315
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/316
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/317
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/318
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/319
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/320
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/321
# Retrieving ... oai:cdm17409.contentdm.oclc.org:rencen/322

# %% [markdown]
# ### Save the dict
#
# In case you want to use it later as a feeder file or for later transformation.

# %%
# write the data to a local file for reference
import json

metadata_file = 'rencen_set_info.json'

with open(metadata_file, 'w', encoding='utf-8') as f:
    json.dump(rencen_set_info, f)
