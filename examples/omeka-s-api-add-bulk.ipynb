# %% [markdown]
# # Omeka S API - Sample bulk upload scripts
#
# These scripts were created based on the code in the individual item notebook,
# with changes and code creation by claude.ai in December 2024.

# %%
import requests
import csv
import json
import os

# %%
def import_omeka_items(csv_path, media_directory, site_api, item_set_id, key_identity, key_credential):
    """
    Import items and their associated media files to an Omeka S site via API.
    
    Parameters:
    - csv_path: Path to the CSV file containing item metadata
    - media_directory: Directory containing media files
    - site_api: Base URL of the Omeka S API
    - item_set_id: ID of the Omeka S item set to add items to
    - key_identity: API key identity
    - key_credential: API key credential
    
    Returns:
    - List of response statuses for each item import
    """
    # API endpoint for items
    action = '/items'
    
    # Prepare API authentication parameters
    params = {
        'key_credential': key_credential,
        'key_identity': key_identity,
    }
    
    # Store import results
    import_results = []
    
    # Read the CSV file
    with open(csv_path, 'r', encoding='utf-8') as csvfile:
        # Assume the first row contains headers
        reader = csv.DictReader(csvfile)
        
        # Process each row in the CSV
        for row_index, row in enumerate(reader):
            # Prepare files dictionary for this item
            files = {}
            
            # Construct item metadata
            item_metadata = {
                "@type": "o:Item",
                "o:item_set": [{"o:id": item_set_id}],
                "o:media": []
            }
            
            # Add title (adjust field name as needed)
            if 'title' in row:
                item_metadata['dcterms:title'] = [{
                    "property_id": 1,
                    "property_label": "Title",
                    "@value": row['title'],
                    "type": "literal"
                }]
            
            # Add other metadata fields dynamically (customize as needed)
            for key, value in row.items():
                # Skip empty values and special fields
                if key.lower() == 'title' or not value:
                    continue
                
                # You might need to map CSV column names to Omeka property IDs
                # This is a placeholder and should be customized based on your specific metadata schema
                item_metadata[f'dcterms:{key}'] = [{
                    "property_id": 1,  # This should be replaced with correct property ID
                    "property_label": key.capitalize(),
                    "@value": value,
                    "type": "literal"
                }]
            
            # Find and add media files
            # Assumes there's a unique identifier in the CSV that matches part of the media filename
            media_files = []
            for filename in os.listdir(media_directory):
                # Customize the matching logic based on your file naming convention
                if any(identifier.lower() in filename.lower() for identifier in row.values()):
                    media_path = os.path.join(media_directory, filename)
                    media_files.append(media_path)
            
            # Prepare media files for upload
            for file_index, media_file_path in enumerate(media_files):
                files[f'file[{file_index}]'] = open(media_file_path, 'rb')
                
                # Add media metadata
                item_metadata['o:media'].append({
                    "o:ingester": "upload",
                    "file_index": str(file_index),
                    "o:item": {},
                    "dcterms:title": [{
                        "property_id": 1,
                        "property_label": "Title",
                        "@value": f"Media file for {row.get('title', 'item')}",
                        "type": "literal"
                    }]
                })
            
            # Add item metadata to files
            files['data'] = (None, json.dumps(item_metadata))
            
            try:
                # Send API request to create item
                r = requests.post(site_api + action, params=params, files=files)
                import_results.append({
                    'row': row_index,
                    'status_code': r.status_code,
                    'url': r.url,
                    'response': r.text
                })
                
                # Close any open file handles
                for file_obj in files.values():
                    if hasattr(file_obj, 'close'):
                        file_obj[1].close()
            
            except Exception as e:
                import_results.append({
                    'row': row_index,
                    'error': str(e)
                })
    
    return import_results

# %%
# Example usage
if __name__ == '__main__':
    results = import_omeka_items(
        csv_path='path/to/your/metadata.csv',
        media_directory='path/to/media/files',
        site_api='http://your-omeka-s-site/api',
        item_set_id=100, # input your set ID here, if desired
        key_identity='key-identity-for-your-API-user-agent',
        key_credential='key-credential-for-your-API-user-agent'
    )
    
    # Print import results
    for result in results:
        print(result)

# %%
# usage in practice
if __name__ == '__main__':
    results = import_omeka_items(
        csv_path='../collection-project/collection_items_data.csv',
        media_directory='../collection-project/item-files',
        site_api='http://jajohnst.si676.si.umich.edu/omeka-s/api',
        item_set_id=654,
        key_identity='yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j',
        key_credential='nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky'
    )
    
    # Print import results
    for result in results:
        print(result)
# Out:
# {'row': 0, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/655","@type":"o:Item","o:id":655,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Carnegie Library, Cordele, Georgia","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Carnegie Library, Cordele, Georgia"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-cph.3b41963.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"91787443"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1916-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/91787443\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/cph\\/3b40000\\/3b41000\\/3b41900\\/3b41963v.jpg#h=823\\u0026w=1024"}]}'}
# {'row': 1, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/656","@type":"o:Item","o:id":656,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Silence \\/ Mabel Dwight.","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Silence \\/ Mabel Dwight."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-cph.3b43255.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"89710983"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1939-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/89710983\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication. For more information, see Federal Art Project (FAP) Prints  - Rights and Restrictions Information http:\\/\\/hdl.loc.gov\\/loc.pnp\\/res.750.fap"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Did not identify a URL."}]}'}
# {'row': 2, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/657","@type":"o:Item","o:id":657,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Carnegie Library, Sheldon, Iowa","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Carnegie Library, Sheldon, Iowa"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-cph.3c18157.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"97511671"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1909-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/97511671\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Undetermined"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/cph\\/3c10000\\/3c18000\\/3c18100\\/3c18157v.jpg#h=824\\u0026w=1024"}]}'}
# {'row': 3, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/658","@type":"o:Item","o:id":658,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:44+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-cph.3f05168.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"98508385"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1936-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/98508385\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/cph\\/3f00000\\/3f05000\\/3f05100\\/3f05168v.jpg#h=1024\\u0026w=708"}]}'}
# {'row': 4, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/659","@type":"o:Item","o:id":659,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"For greater knowledge on more subjects use your library more often","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"For greater knowledge on more subjects use your library more often"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-cph.3f05183.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"98508155"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1936-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/98508155\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/cph\\/3f00000\\/3f05000\\/3f05100\\/3f05183v.jpg#h=1024\\u0026w=705"}]}'}
# {'row': 5, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/660","@type":"o:Item","o:id":660,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"[Cossitt Library, Memphis, Tenn.]","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"[Cossitt Library, Memphis, Tenn.]"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-det.4a17925.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2016809661"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1906-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2016809661\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/det\\/4a10000\\/4a17000\\/4a17900\\/4a17925v.jpg#h=814\\u0026w=1024"}]}'}
# {'row': 6, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/661","@type":"o:Item","o:id":661,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Little Rock Public Library, Little Rock, Ark.","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Little Rock Public Library, Little Rock, Ark."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-det.4a23603.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2016815290"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1905-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2016815290\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/det\\/4a20000\\/4a23000\\/4a23600\\/4a23603v.jpg#h=820\\u0026w=1024"}]}'}
# {'row': 7, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/662","@type":"o:Item","o:id":662,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Buffalo, N.Y. -  Public library - children\\u0027s room","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:45+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Buffalo, N.Y. -  Public library - children\\u0027s room"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ds.06507.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2014650180"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1900-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2014650180\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Did not identify a URL."}]}'}
# {'row': 8, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/663","@type":"o:Item","o:id":663,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Main public library building - Detroit","thumbnail_display_urls":{"large":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/files\\/large\\/8e19da3f1190b26db8d9b0b5e0b67b08a42e6d6c.jpg","medium":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/files\\/medium\\/8e19da3f1190b26db8d9b0b5e0b67b08a42e6d6c.jpg","square":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/files\\/square\\/8e19da3f1190b26db8d9b0b5e0b67b08a42e6d6c.jpg"},"o:created":{"@value":"2024-12-07T15:34:46+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:46+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/media\\/664","o:id":664},"o:media":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/media\\/664","o:id":664}],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Main public library building - Detroit"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ds.06560.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2014647618"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1921"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2014647618\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Did not identify a URL."}]}'}
# {'row': 8, 'error': "'_io.BufferedReader' object is not subscriptable"}
# {'row': 9, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/665","@type":"o:Item","o:id":665,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Newspaper reading room of public library. Omaha, Nebraska","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Newspaper reading room of public library. Omaha, Nebraska"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-fsa.8b14169.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2017762724"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1938-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2017762724\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions. For information, see U.S. Farm Security Administration\\/Office of War Information Black \\u0026 White Photographs https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/071_fsab.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/fsa\\/8b14000\\/8b14100\\/8b14169v.jpg#h=783\\u0026w=1024"}]}'}
# {'row': 10, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/666","@type":"o:Item","o:id":666,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Public library in the southwestern section of Mississippi, in the piney woods","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Public library in the southwestern section of Mississippi, in the piney woods"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-fsa.8b32222.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2017770391"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1937-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2017770391\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions. For information, see U.S. Farm Security Administration\\/Office of War Information Black \\u0026 White Photographs https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/071_fsab.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/fsa\\/8b32000\\/8b32200\\/8b32222v.jpg#h=1024\\u0026w=963"}]}'}
# {'row': 11, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/667","@type":"o:Item","o:id":667,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:47+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Library tent at the FSA (Farm Security Administration) mobile camp for migratory farm workers. Odell, Oregon. The girls working in the library receive credit in the Junior Campers League for work in the library"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-fsa.8c22565.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2017815837"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1941-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2017815837\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions. For information, see U.S. Farm Security Administration\\/Office of War Information Black \\u0026 White Photographs https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/071_fsab.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/fsa\\/8c22000\\/8c22500\\/8c22565v.jpg#h=787\\u0026w=1024"}]}'}
# {'row': 12, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/668","@type":"o:Item","o:id":668,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-fsa.8d24709.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2017843202"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1943-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2017843202\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions. For information, see U.S. Farm Security Administration\\/Office of War Information Black \\u0026 White Photographs https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/071_fsab.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/fsa\\/8d24000\\/8d24700\\/8d24709v.jpg#h=1024\\u0026w=976"}]}'}
# {'row': 13, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/669","@type":"o:Item","o:id":669,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Libraries, Washington D.C.","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Libraries, Washington D.C."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-g3851e.ct006252.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"87694100"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1926-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/87694100\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027map\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:map\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Undetermined"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/image-services\\/iiif\\/service:gmd:gmd385:g3851:g3851e:ct006252\\/full\\/pct:25\\/0\\/default.jpg#h=1205\\u0026w=1684"}]}'}
# {'row': 14, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/670","@type":"o:Item","o:id":670,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Juneau Public Library, 292 Marine Way, Juneau, Juneau Borough, AK","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Juneau Public Library, 292 Marine Way, Juneau, Juneau Borough, AK"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-hhh.ak0345.photos.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"ak0345"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Not found"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/ak0345\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on images made by the U.S. Government; images     copied from other sources may be restricted.    https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/114_habs.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Did not identify a URL."}]}'}
# {'row': 15, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/671","@type":"o:Item","o:id":671,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Georgetown University, Healy Building, Thirty-seventh \\u0026 O Streets, Northwest, Washington, District of Columbia, DC","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:34:48+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Georgetown University, Healy Building, Thirty-seventh \\u0026 O Streets, Northwest, Washington, District of Columbia, DC"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-hhh.dc0121.photos.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"dc0121"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Not found"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/dc0121\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on images made by the U.S. Government; images     copied from other sources may be restricted.    https:\\/\\/www.loc.gov\\/rr\\/print\\/res\\/114_habs.html"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Did not identify a URL."}]}'}
# ...
# {'row': 114, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/771","@type":"o:Item","o:id":771,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"[Carnegie library in Pittsburgh, Pennsylvania]","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"[Carnegie library in Pittsburgh, Pennsylvania]"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ppmsca.15412.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2007684172"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1900-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2007684172\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/ppmsca\\/15400\\/15412v.jpg#h=779\\u0026w=1024"}]}'}
# {'row': 115, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/772","@type":"o:Item","o:id":772,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"Main entrance. Boston Public Library","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Main entrance. Boston Public Library"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ppmsca.15426.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2007682033"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1895-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2007682033\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/ppmsca\\/15400\\/15426v.jpg#h=1024\\u0026w=822"}]}'}
# {'row': 116, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/773","@type":"o:Item","o:id":773,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"The Library of Congress, Washington","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"The Library of Congress, Washington"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ppmsca.18016.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2008678216"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1902-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2008678216\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/ppmsca\\/18000\\/18016v.jpg#h=755\\u0026w=1024"}]}'}
# {'row': 117, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/774","@type":"o:Item","o:id":774,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"[Carnegie library, (Taunton, Mass.). Elevation]","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:35:15+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"[Carnegie library, (Taunton, Mass.). Elevation]"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ppmsca.35590.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"96514755"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1903-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/96514755\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/ppmsca\\/35500\\/35590v.jpg#h=642\\u0026w=1024"}]}'}
# {'row': 118, 'status_code': 200, 'url': 'http://jajohnst.si676.si.umich.edu/omeka-s/api/items?key_credential=nj0K6JAqnFgeqyP3Kq40SOhl6fiPBXky&key_identity=yAu5NAEEtJCvGx4s8XgJSgvTFjwvLD6j', 'response': '{"@context":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api-context","@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/items\\/775","@type":"o:Item","o:id":775,"o:is_public":true,"o:owner":{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/users\\/1","o:id":1},"o:resource_class":null,"o:resource_template":null,"o:thumbnail":null,"o:title":"[Interior view of library reading room with male and female students sitting at tables, reading, at the Tuskegee Institute]","thumbnail_display_urls":{"large":null,"medium":null,"square":null},"o:created":{"@value":"2024-12-07T15:35:16+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:modified":{"@value":"2024-12-07T15:35:16+00:00","@type":"http:\\/\\/www.w3.org\\/2001\\/XMLSchema#dateTime"},"o:primary_media":null,"o:media":[],"o:item_set":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/item_sets\\/654","o:id":654}],"o:site":[{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/1","o:id":1},{"@id":"http:\\/\\/jajohnst.si676.si.umich.edu\\/omeka-s\\/api\\/sites\\/2","o:id":2}],"dcterms:title":[{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"[Interior view of library reading room with male and female students sitting at tables, reading, at the Tuskegee Institute]"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Item"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2024-12-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"..\\/collection-project\\/item-metadata\\/item_metadata-ppmscd.00084.json"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"2009632000"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"1902-01-01"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/www.loc.gov\\/item\\/2009632000\\/"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"{\\u0027photo, print, drawing\\u0027: \\u0027https:\\/\\/www.loc.gov\\/search\\/?fa=original_format:photo,+print,+drawing\\u0026fo=json\\u0027}"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"Image"},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"No known restrictions on publication."},{"type":"literal","property_id":1,"property_label":"Title","is_public":true,"@value":"https:\\/\\/tile.loc.gov\\/storage-services\\/service\\/pnp\\/ppmscd\\/00000\\/00084v.jpg#h=829\\u0026w=1024"}]}'}
